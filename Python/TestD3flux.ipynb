# %%
import cobra
from cobra.core import Metabolite, Reaction, Model
from d3flux import flux_map
import cobra.test

# %%
model = Model('simple_model')

A = Metabolite('A')
B = Metabolite('B')
C = Metabolite('C')
D = Metabolite('D')
E = Metabolite('O')
P = Metabolite('P')

R1 = Reaction('R1')
R2 = Reaction('R2')
R3 = Reaction('R3')
R4 = Reaction('R4')
R5 = Reaction('R5')
R6 = Reaction('R6')
R7 = Reaction('R7')
R8 = Reaction('R8')
R9 = Reaction('R9')
R10 = Reaction('R10')

model.add_metabolites([A, B, C, D, E, P])
model.add_reactions([R1, R2, R3, R4, R5, R6, R7, R8, R9, R10])

model.reactions.R1.build_reaction_from_string('--> A')
model.reactions.R2.build_reaction_from_string('<--> B')
model.reactions.R3.build_reaction_from_string('P -->')
model.reactions.R4.build_reaction_from_string('O -->')
model.reactions.R5.build_reaction_from_string('A --> B')
model.reactions.R6.build_reaction_from_string('A --> C')
model.reactions.R7.build_reaction_from_string('A --> D')
model.reactions.R8.build_reaction_from_string('B <--> C')
model.reactions.R9.build_reaction_from_string('B --> P')
model.reactions.R10.build_reaction_from_string('C + D --> O')
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %%
flux_map(model, display_name_format=lambda x: str(x.id), figsize=(300,250),
         flux_dict={rxn.id: None for rxn in model.reactions})
# Out:
# <div id="d3flux001">
#
# </div>
# <div id="d3flux001_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux001model = {"metabolites": [{"id": "A", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "A"}}}, {"id": "B", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "B"}}}, {"id": "C", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "C"}}}, {"id": "D", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "D"}}}, {"id": "O", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "O"}}}, {"id": "P", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "P"}}}], "reactions": [{"id": "R1", "name": "", "metabolites": {"A": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true}}}, {"id": "R2", "name": "", "metabolites": {"B": 1}, "lower_bound": -1000.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": true, "hidden": true}}}, {"id": "R3", "name": "", "metabolites": {"P": -1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true}}}, {"id": "R4", "name": "", "metabolites": {"O": -1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true}}}, {"id": "R5", "name": "", "metabolites": {"A": -1, "B": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false}}}, {"id": "R6", "name": "", "metabolites": {"A": -1, "C": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false}}}, {"id": "R7", "name": "", "metabolites": {"A": -1, "D": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false}}}, {"id": "R8", "name": "", "metabolites": {"B": -1, "C": 1}, "lower_bound": -1000.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": true}}}, {"id": "R9", "name": "", "metabolites": {"B": -1, "P": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false}}}, {"id": "R10", "name": "", "metabolites": {"C": -1, "D": -1, "O": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false}}}], "genes": [], "id": "simple_model", "compartments": {}, "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     jQuery: 'https://code.jquery.com/jquery-2.2.4.min',
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "https://cdn.jsdelivr.net/gh/tgdwyer/WebCola@v3/WebCola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     },
#     'jQuery': {
#       exports: 'jQuery'
#     }
#   }
# });
#
# require(["jQuery", "cola", "d3", "math", "FileSaver"], function (jQuery, cola,
# 	d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       // .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#       //         "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .range(["#bbb", "#d62728",
#         "#eb6a9b",
#         "#6f3589",
#         "#f18572",
#         "#246035",
#         "#009fea",
#         "#83522b",
#         "#29378a",
#         "#989033"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = cola.d3adaptor()
#       .linkDistance(30)
#
#       .size([width, height]);
#     // var force = d3.layout.force()
#     //   .linkDistance(30)
#     //   .charge(-100)
#     //   .chargeDistance(400)
#     //   .gravity(.015)
#     //   .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux001").append("svg")
#         .attr("viewBox", "0 0 300 250")
#         .attr("style", "display:block;margin:auto;width:100%");
#     } else {
#       var svg = d3.select("#d3flux001").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{font-size:12pt;fill:#555;font-family:Arial}text.nodelabel.cofactor{font-size:9.600000000000001pt;fill:#789}text.nodelabel.rxn{fill:#a9a9a9;font-size:9.600000000000001pt;font-style:italic}marker.inactive,.node.inactive,text.inactive{fill-opacity:1.0}.link.inactive{stroke-opacity:1.0}");
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux001_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux001_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       e.setAttribute('src', 'https://rawgit.com/pstjohn/svg-crowbar/gh-pages/svg-crowbar.js');
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
#       for (var n in rstoich) {
#         if (!('cofactor' in nodes[n])) {
#           var angle = calc_imag_angle(rxn.x, rxn.y, nodes[n].x, nodes[n].y);
#           angles.push([math.multiply(angle, rstoich[n])]);
#         }
#       }
#       return math.mean(angles).toPolar().phi;
#     }
#
#     function average_dist(rxn, rstoich, nodes) {
#       // Calculate the average distance to the reaction nodes, which is used to
#       var dist = []
#       for (var n in rstoich) {
#         var this_dist = mat

# %%
for reaction in model.reactions:
	print(str(reaction.id)+" : "+str(reaction.reaction))
# Out:
# R1 :  --> A
# R2 :  <=> B
# R3 : P -->
# R4 : O -->
# R5 : A --> B
# R6 : A --> C
# R7 : A --> D
# R8 : B <=> C
# R9 : B --> P
# R10 : C + D --> O

# %%
model.objective=model.reactions.R4
model.optimize()
flux_map(model, figsize=(300,250))
# Out:
# <div id="d3flux002">
#
# </div>
# <div id="d3flux002_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux002model = {"metabolites": [{"id": "A", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "A", "flux": 1000.0}}}, {"id": "B", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "B", "flux": 1000.0}}}, {"id": "C", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "C", "flux": 1000.0}}}, {"id": "D", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "D", "flux": 1000.0}}}, {"id": "O", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "O", "flux": 1000.0}}}, {"id": "P", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "P", "flux": 0.0}}}], "reactions": [{"id": "R1", "name": "", "metabolites": {"A": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}}, {"id": "R2", "name": "", "metabolites": {"B": 1}, "lower_bound": -1000.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": true, "hidden": true, "flux": 1000.0}}}, {"id": "R3", "name": "", "metabolites": {"P": -1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 0.0}}}, {"id": "R4", "name": "", "metabolites": {"O": -1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "objective_coefficient": 1.0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}}, {"id": "R5", "name": "", "metabolites": {"A": -1, "B": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 0.0}}}, {"id": "R6", "name": "", "metabolites": {"A": -1, "C": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 0.0}}}, {"id": "R7", "name": "", "metabolites": {"A": -1, "D": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 1000.0}}}, {"id": "R8", "name": "", "metabolites": {"B": -1, "C": 1}, "lower_bound": -1000.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": true, "flux": 1000.0}}}, {"id": "R9", "name": "", "metabolites": {"B": -1, "P": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 0.0}}}, {"id": "R10", "name": "", "metabolites": {"C": -1, "D": -1, "O": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 1000.0}}}], "genes": [], "id": "simple_model", "compartments": {}, "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     jQuery: 'https://code.jquery.com/jquery-2.2.4.min',
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "https://cdn.jsdelivr.net/gh/tgdwyer/WebCola@v3/WebCola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     },
#     'jQuery': {
#       exports: 'jQuery'
#     }
#   }
# });
#
# require(["jQuery", "cola", "d3", "math", "FileSaver"], function (jQuery, cola,
# 	d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       // .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#       //         "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .range(["#bbb", "#d62728",
#         "#eb6a9b",
#         "#6f3589",
#         "#f18572",
#         "#246035",
#         "#009fea",
#         "#83522b",
#         "#29378a",
#         "#989033"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = cola.d3adaptor()
#       .linkDistance(30)
#
#       .size([width, height]);
#     // var force = d3.layout.force()
#     //   .linkDistance(30)
#     //   .charge(-100)
#     //   .chargeDistance(400)
#     //   .gravity(.015)
#     //   .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux002").append("svg")
#         .attr("viewBox", "0 0 300 250")
#         .attr("style", "display:block;margin:auto;width:100%");
#     } else {
#       var svg = d3.select("#d3flux002").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{font-size:12pt;fill:#555;font-family:Arial}text.nodelabel.cofactor{font-size:9.600000000000001pt;fill:#789}text.nodelabel.rxn{fill:#a9a9a9;font-size:9.600000000000001pt;font-style:italic}marker.inactive,.node.inactive,text.inactive{fill-opacity:1.0}.link.inactive{stroke-opacity:1.0}");
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux002_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux002_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       e.setAttribute('src', 'https://rawgit.com/pstjohn/svg-crowbar/gh-pages/svg-crowbar.js');
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
#       for (var n in rstoich) {
#         if (!('cofactor' in nodes[n])) {
#           var angle = calc_imag_angle(rxn.x, rxn.y, nodes[n].x, nodes[n].y);
#           angles.push([math.multiply(angle, rstoich[n])]);

# %%
print(model.summary())
# Out:
# Objective
# =========
# 1.0 R4 = 1000.0
#
# Uptake
# ------
# Metabolite Reaction Flux  C-Number C-Flux
#          A       R1 1000         0  0.00%
#          B       R2 1000         0  0.00%
#
# Secretion
# ---------
# Metabolite Reaction  Flux  C-Number C-Flux
#          E       R4 -1000         0  0.00%

# %%
model.reactions.R8.knock_out()
solution_test=model.optimize()
flux_map(model, figsize=(300,250))
# Out:
# <div id="d3flux003">
#
# </div>
# <div id="d3flux003_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux003model = {"metabolites": [{"id": "A", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "A", "flux": 1000.0}}}, {"id": "B", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "B", "flux": 0.0}}}, {"id": "C", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "C", "flux": 500.0}}}, {"id": "D", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "D", "flux": 500.0}}}, {"id": "O", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "O", "flux": 500.0}}}, {"id": "P", "name": "", "compartment": "", "notes": {"map_info": {"display_name": "P", "flux": 0.0}}}], "reactions": [{"id": "R1", "name": "", "metabolites": {"A": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 1000.0}}}, {"id": "R2", "name": "", "metabolites": {"B": 1}, "lower_bound": -1000.0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": true, "hidden": true, "flux": 0.0}}}, {"id": "R3", "name": "", "metabolites": {"P": -1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 0.0}}}, {"id": "R4", "name": "", "metabolites": {"O": -1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "objective_coefficient": 1.0, "notes": {"map_info": {"reversibility": false, "hidden": true, "flux": 500.0}}}, {"id": "R5", "name": "", "metabolites": {"A": -1, "B": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 0.0}}}, {"id": "R6", "name": "", "metabolites": {"A": -1, "C": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 500.0}}}, {"id": "R7", "name": "", "metabolites": {"A": -1, "D": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 500.0}}}, {"id": "R8", "name": "", "metabolites": {"B": -1, "C": 1}, "lower_bound": 0, "upper_bound": 0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "group": "ko"}}}, {"id": "R9", "name": "", "metabolites": {"B": -1, "P": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 0.0}}}, {"id": "R10", "name": "", "metabolites": {"C": -1, "D": -1, "O": 1}, "lower_bound": 0, "upper_bound": 1000.0, "gene_reaction_rule": "", "notes": {"map_info": {"reversibility": false, "flux": 500.0}}}], "genes": [], "id": "simple_model", "compartments": {}, "notes": {"map_info": {}}};
#
# require.config({
#   paths: {
#     jQuery: 'https://code.jquery.com/jquery-2.2.4.min',
#     d3: "https://d3js.org/d3.v3.min",
#     cola: "https://cdn.jsdelivr.net/gh/tgdwyer/WebCola@v3/WebCola/cola.v3.min",
#     math: "https://cdnjs.cloudflare.com/ajax/libs/mathjs/2.4.0/math.min",
#     FileSaver: "https://cdnjs.cloudflare.com/ajax/libs/FileSaver.js/2014-11-29/FileSaver.min",
#   },
#   shim: {
#     'cola': {
#       exports: 'cola'
#     },
#     'jQuery': {
#       exports: 'jQuery'
#     }
#   }
# });
#
# require(["jQuery", "cola", "d3", "math", "FileSaver"], function (jQuery, cola,
# 	d3, math, FileSaver) {
#
#   function main(model) {
#     // Render a metabolic network representation of a cobra.Model object.
#     //
#     // `model` is a json-serialized representation of a metabolic network,
#     // generated by cobra.display.flux_analysis.create_model_json
#
#     // Height and width of the SVG figure, passed via jinja2
#     var width = 300,
#     height = 250;
#
#     // var color = d3.scale.category10();
#
#     // Reaction color allows different reaction groups to be colored
#     // accordingly. Grouping is mainly handled by color_redox_reactions. First
#     // group ('undefined') is for normal reactions (gray). Second group is for
#     // knocked-out reactions, (red). Others are rendered in different
#     // contrasting colors
#     var rxncolor = d3.scale.ordinal()
#       // .range(["#bbb", "#d62728", "#ff7f0e", "#2ca02c", "#9467bd",
#       //         "#8c564b", "#e377c2", "#7f7f7f", "#bcbd22", "#17becf"])
#       .range(["#bbb", "#d62728",
#         "#eb6a9b",
#         "#6f3589",
#         "#f18572",
#         "#246035",
#         "#009fea",
#         "#83522b",
#         "#29378a",
#         "#989033"])
#       .domain([undefined, 'ko', 1, 2, 3, 4, 5, 6, 7, 8]);
#
#     // Initialize the d3 force diagram. Parameters like charge, gavity, and
#     // link distance are currently hard-coded in -- probably should change
#     // this?
#     var force = cola.d3adaptor()
#       .linkDistance(30)
#
#       .size([width, height]);
#     // var force = d3.layout.force()
#     //   .linkDistance(30)
#     //   .charge(-100)
#     //   .chargeDistance(400)
#     //   .gravity(.015)
#     //   .size([width, height]);
#
#     // Allow for a background SVG template if one has been provided, otherwise
#     // initalize the svg canvas
#     if (true) {
#       var svg = d3.select("#d3flux003").append("svg")
#         .attr("viewBox", "0 0 300 250")
#         .attr("style", "display:block;margin:auto;width:100%");
#     } else {
#       var svg = d3.select("#d3flux003").select("svg");
#     }
#
#     // Append the CSS styles
#     svg.append("style").text(".node.rxn{fill:#ffa319}.node.rxn.hidden{fill:none;stroke:none;stroke-width:0}.link{fill:none;stroke-linecap:round}text.nodelabel{font-size:12pt;fill:#555;font-family:Arial}text.nodelabel.cofactor{font-size:9.600000000000001pt;fill:#789}text.nodelabel.rxn{fill:#a9a9a9;font-size:9.600000000000001pt;font-style:italic}marker.inactive,.node.inactive,text.inactive{fill-opacity:1.0}.link.inactive{stroke-opacity:1.0}");
#
#     // Code for the figure manipulation buttons.
#     d3.select("#d3flux003_options .reactionbutton").on("click", function() {
#       // Show/hide the reaction control node points.
#       var $this = $(this);
#       $this.toggleClass('btn-danger');
#       d3.selectAll(".node.rxn")
#         .classed("hidden", function (d, i) {
#           return !d3.select(this).classed("hidden");
#         });
#       if($this.hasClass('btn-danger')){
#         $this.text('Hide Reaction Nodes');
#       } else {
#         $this.text('Show Reaction Nodes');
#       }
#     });
#
#     d3.select("#d3flux003_options .svgbutton").on("click", function() {
#       // Download the svg using SVG Crowbar. This is still very buggy.
#
#       var e = document.createElement('script');
#       e.setAttribute('src', 'https://rawgit.com/pstjohn/svg-crowbar/gh-pages/svg-crowbar.js');
#       e.setAttribute('class', 'svg-crowbar');
#       document.body.appendChild(e);
#     });
#
#     function calc_imag_angle(x1, y1, x2, y2) {
#       // Function to calculate the imaginary angle of the line between two
#       // points. Used to find the average direction to the metabolites of a
#       // reaction node
#       var calcAngleVal = Math.atan2(x1-x2,y1-y2);
#       return math.exp(math.multiply(math.i, calcAngleVal));
#     }
#
#     function average_angles(rxn, rstoich, nodes) {
#       // Find the slope of the line through the reaction node as a function of
#       // the current position of the metabolites. Reactants and products are
#       // separated and placed on opposite ends of the nodes.
#       //
#       // Looks like for cofactors, rstoich could be set to zero to remove the
#       // effect on the reaction slope.
#       var angles = []
#       for (var n in rstoich) {
#         if (!('cofactor' in nodes[n])) {
#           var angle = calc_imag_angle(rxn.x, rxn.y, nodes[n].x, nodes[n].y);
#           angles.push([math.multiply(angle, rstoich[n])]);
#         }
#       }
#       retu

# %%
print(solution_test)
print(model.summary())
# Out:
# <Solution 500.000 at 0x7f3af17662c0>
# Objective
# =========
# 1.0 R4 = 500.0
#
# Uptake
# ------
# Metabolite Reaction Flux  C-Number C-Flux
#          A       R1 1000         0  0.00%
#
# Secretion
# ---------
# Metabolite Reaction Flux  C-Number C-Flux
#          O       R4 -500         0  0.00%

# %%
textbook_model = cobra.test.create_test_model("textbook")

# %%
#flux_map(textbook_model, display_name_format=lambda x: str(x.id), figsize=(300,250),
#         flux_dict={rxn.id: None for rxn in textbook_model.reactions})
#ATTENTION : ILLISBLE
# Out:
# <div id="d3flux004">
#
# </div>
# <div id="d3flux004_options">
#   <button type="button" class="download btn btn-primary">Save JSON</button>
#   <button type="button" class="reactionbutton btn btn-success ">Show Reaction Nodes</button>
#   <button type="button" class="svgbutton btn btn-info ">Download SVG</button>
# </div>
# <script type="text/Javascript">
# var d3flux004model = {"metabolites": [{"id": "13dpg_c", "name": "3-Phospho-D-glyceroyl phosphate", "compartment": "c", "charge": -4, "formula": "C3H4O10P2", "notes": {"map_info": {"display_name": "13dpg_c"}}, "annotation": {"bigg.metabolite": "13dpg", "biocyc": "DPG", "chebi": ["CHEBI:16001", "CHEBI:1658", "CHEBI:20189", "CHEBI:57604", "CHEBI:11881"], "hmdb": "HMDB01270", "kegg.compound": "C00236", "pubchem.substance": "3535", "reactome": "REACT_29800", "seed.compound": "cpd00203", "unipathway.compound": "UPC00236"}}, {"id": "2pg_c", "name": "D-Glycerate 2-phosphate", "compartment": "c", "charge": -3, "formula": "C3H4O7P", "notes": {"map_info": {"display_name": "2pg_c"}}, "annotation": {"bigg.metabolite": "2pg", "biocyc": "2-PG", "chebi": ["CHEBI:1267", "CHEBI:58289", "CHEBI:17835", "CHEBI:21028", "CHEBI:11651", "CHEBI:12986", "CHEBI:24344", "CHEBI:39868"], "hmdb": ["HMDB03391", "HMDB00362"], "kegg.compound": "C00631", "pubchem.substance": "3904", "reactome": "REACT_30485", "seed.compound": "cpd00482", "unipathway.compound": "UPC00631"}}, {"id": "3pg_c", "name": "3-Phospho-D-glycerate", "compartment": "c", "charge": -3, "formula": "C3H4O7P", "notes": {"map_info": {"display_name": "3pg_c"}}, "annotation": {"bigg.metabolite": "3pg", "biocyc": "G3P", "chebi": ["CHEBI:40016", "CHEBI:58272", "CHEBI:57998", "CHEBI:11879", "CHEBI:1657", "CHEBI:1659", "CHEBI:17050", "CHEBI:21029", "CHEBI:11882", "CHEBI:11880", "CHEBI:12987", "CHEBI:17794", "CHEBI:24345"], "hmdb": "HMDB00807", "kegg.compound": ["C00197", "C00597"], "pubchem.substance": "3497", "reactome": "REACT_29728", "seed.compound": "cpd00169", "unipathway.compound": ["UPC00597", "UPC00197"]}}, {"id": "6pgc_c", "name": "6-Phospho-D-gluconate", "compartment": "c", "charge": -3, "formula": "C6H10O10P", "notes": {"map_info": {"display_name": "6pgc_c"}}, "annotation": {"bigg.metabolite": "6pgc", "biocyc": "CPD-2961", "chebi": ["CHEBI:2231", "CHEBI:12232", "CHEBI:48928", "CHEBI:16863", "CHEBI:58759", "CHEBI:40282", "CHEBI:33851"], "hmdb": "HMDB01316", "kegg.compound": "C00345", "pubchem.substance": "3638", "reactome": "REACT_29996", "seed.compound": "cpd00284", "unipathway.compound": "UPC00345"}}, {"id": "6pgl_c", "name": "6-phospho-D-glucono-1,5-lactone", "compartment": "c", "charge": -2, "formula": "C6H9O9P", "notes": {"map_info": {"display_name": "6pgl_c"}}, "annotation": {"bigg.metabolite": "6pgl", "biocyc": "D-6-P-GLUCONO-DELTA-LACTONE", "chebi": ["CHEBI:16938", "CHEBI:12233", "CHEBI:4160", "CHEBI:20989", "CHEBI:57955", "CHEBI:12958"], "hmdb": "HMDB01127", "kegg.compound": "C01236", "pubchem.substance": "4457", "reactome": "REACT_31467", "seed.compound": "cpd00911", "unipathway.compound": "UPC01236"}}, {"id": "ac_c", "name": "Acetate", "compartment": "c", "charge": -1, "formula": "C2H3O2", "notes": {"map_info": {"display_name": "ac_c"}}, "annotation": {"bigg.metabolite": "ac", "biocyc": "ACET", "cas": ["71-50-1"], "chebi": ["CHEBI:62947", "CHEBI:62964", "CHEBI:32029", "CHEBI:22165", "CHEBI:3310", "CHEBI:2387", "CHEBI:62984", "CHEBI:63879", "CHEBI:32138", "CHEBI:15366", "CHEBI:13704", "CHEBI:63078", "CHEBI:30089", "CHEBI:40480", "CHEBI:22169", "CHEBI:40486", "CHEBI:59199", "CHEBI:63045", "CHEBI:32954"], "hmdb": "HMDB00042", "kegg.compound": "C00033", "kegg.drug": "D00010", "lipidmaps": ["LMFA01010000", "LMFA01010002"], "pubchem.substance": "3335", "reactome": ["REACT_113539", "REACT_2022890", "REACT_29416", "REACT_1524044", "REACT_390305"], "seed.compound": "cpd00029", "unipathway.compound": "UPC00033"}}, {"id": "ac_e", "name": "Acetate", "compartment": "e", "charge": -1, "formula": "C2H3O2", "notes": {"map_info": {"display_name": "ac_e"}}, "annotation": {"bigg.metabolite": "ac", "biocyc": "ACET", "cas": ["71-50-1"], "chebi": ["CHEBI:62947", "CHEBI:62964", "CHEBI:32029", "CHEBI:22165", "CHEBI:3310", "CHEBI:2387", "CHEBI:62984", "CHEBI:63879", "CHEBI:32138", "CHEBI:15366", "CHEBI:13704", "CHEBI:63078", "CHEBI:30089", "CHEBI:40480", "CHEBI:22169", "CHEBI:40486", "CHEBI:59199", "CHEBI: ...

# %%
solution=textbook_model.optimize()
print(solution.fluxes)
print(solution)
# Out:
# ACALD     0.000000
# ACALDt    0.000000
# ACKr      0.000000
# ACONTa    6.007250
# ACONTb    6.007250
#             ...
# TALA      1.496984
# THD2      0.000000
# TKT1      1.496984
# TKT2      1.181498
# TPI       7.477382
# Name: fluxes, Length: 95, dtype: float64
# <Solution 0.874 at 0x7f5a909b8490>

# %%
recon3D=cobra.io.load_json_model("Recon3D.json")

# %%
for x in recon3D.reactions :
    if x.id=="MALTe":
        print("%s : %s" % (x.id, x.reaction))
# Out:
# MALTe : h2o_e + malt_e --> 2.0 glc__D_e

# %%
MALTe = recon3D.reactions.get_by_id("MALTe")
print(MALTe.genes)
gene_MALTe=recon3D.genes.get_by_id("8972_AT1") 
print(gene_MALTe.name)
# Out:
# frozenset({<Gene 8972_AT1 at 0x7f3aeadb67d0>})
# MGAM

# %%
for x in recon3D.genes:
    if x.name.upper().startswith(""):
        reactions_list_str = "{" + ", ".join((i.id for i in x.reactions)) + "}"
        print("%s is associated with reactions: %s" % (x.name, reactions_list_str))
# Out:
#  is associated with reactions: {HDCA24Gtr}
# AOC1 is associated with reactions: {RE3367E, r0281, 42A12BOOX, PTRCOX1, HISTASE, RE0690E, RE0827E, TRYPTAOX, RE0689E, PEAMNO, RE0688E, MHISOR, MAOX, RE0828E, 13DAMPPOX}
# AOC2 is associated with reactions: {42A12BOOX, PTRCOX1, HISTASE, TRYPTAOX, PEAMNO, MHISOR, MAOX, 13DAMPPOX}
# AOC3 is associated with reactions: {MAOX, MHISOR, 42A12BOOX, PTRCOX1, AACTOOR, 13DAMPPOX}
# AOC2 is associated with reactions: {42A12BOOX, PTRCOX1, HISTASE, TRYPTAOX, PEAMNO, MHISOR, MAOX, 13DAMPPOX}
# CYP24A1 is associated with reactions: {24_25VITD2Hm, 24_25VITD3Hm}
# CYP27B1 is associated with reactions: {25HVITD3c, 25VITD2Hm, 25VITD3Hm}
# SDS is associated with reactions: {SERD_L, THRD_L, 2AMACHYD, SERHL}
# SULT1A3 is associated with reactions: {TRIODTHYSULT, HMR_6850, TSTSTERONESULT, PRGNLONESULT, ESTSULT, DHEASULT, CHSTEROLSULT, TYMSULT, HMR_6844, RE0912C, 2AMACSULT, 4NPHSULT, PAPSR, HMR_6838, NRPPHRSULT, DOPASULT4, 5ADTSTSTERONESULT, DOPASULT}
# SLC25A21 is associated with reactions: {2AMADPTm, r0879, 2OXOADPTm}
# UEVLD is associated with reactions: {2HIVc, MCLORi, 2H3MVc, 2HBO, LDH_L, GLXO1}
# LDHB is associated with reactions: {HPYRR2x_1, 2HIVc, MCLORi, 2H3MVc, LDH_L, r0173, LDH_Lm, 2HBO, GLXO1}
# LDHAL6B is associated with reactions: {HPYRR2x_1, 2HIVc, MCLORi, LDH_L, 2HBO, 2H3MVc, GLXO1}
# LDHAL6A is associated with reactions: {HPYRR2x_1, 2HIVc, MCLORi, LDH_L, 2HBO, 2H3MVc, GLXO1}
# LDHC is associated with reactions: {HPYRR2x_1, 2HIVc, MCLORi, LDH_L, 2HBO, 2H3MVc, GLXO1}
# LDHC is associated with reactions: {HPYRR2x_1, 2HIVc, MCLORi, 2H3MVc, LDH_L, r0173, 2HBO, GLXO1}
# LDHA is associated with reactions: {HPYRR2x_1, 2HIVc, MCLORi, 2H3MVc, LDH_L, r0173, LDH_Lm, 2HBO, GLXO1}
# ACOT12 is associated with reactions: {ACOAH, ACOAHim}
# ACOX1 is associated with reactions: {FAOXC226205x, FAOXC2252053x, FAOXC240200x_1, 3OHSUBCOAx, FAOXC2051843x, FAOXC2442246x, FAOXC2452256x, FAOXC183806x, FAOXC2452253x, FAOXC241181x, FAOXC2251836x, FAOXC16080x, FAOXC180x, 3HADICOAx, FAOXC260240x_1, FAOXC200180x, 3OHSEBCOAx, FAOXC18480x, FAOXC2242046x, FAOXC246226x, ACOAO7p}
# ACOX1 is associated with reactions: {HMR_3070, RE3157X, FAOXC140120x, FAOXC101C102m, FAOXC2051843x, HMR_3346, HMR_3338, RE2997X, HMR_3094, FAOXC183806x, FAOXC8C6x, HMR_3342, FAOXC163C164x, HMR_3057, FAOXC142C122x, RE1518M, RE3624M, HMR_3098, HMR_3334, ACOAO4p, FAOXC160140x, FAOXC2252053x, FAOXC240200x_1, FAOXC22C20x, FAOXC161C141x, HMR_3321, r1451, FAOXC2452253x, FAOXC2251836x, ACOAO5p, DEOXFVShc, FAOXC221C201x, RE1516M, 3HADICOAx, FAOXC200180x, FAOXC18480x, FAOXC81C61x, FAOXC6C4x, HMR_3062, ACOAO7p, FAOXC241C221x, RE1516X, FAOXC164C165x, 3OHSUBCOAx, FAOXC143C123x, FAOXC8DCC6DCx, FAOXC2452256x, RE2985X, FAOXC101C102x, FAOXC14DCC12DCx, RE3247X, FAOXC241181x, r1446, FAOXC225C226x, HMR_3066, FAOXC24C22x, FAOXC204C205x, RE1517M, r1444, HMR_3350, 3OHSEBCOAx, RE2985M, FAOXC181C161x, FAOXC246226x, r1448, RE1518X, FAOXC226205x, FAOXC102C103x, FAOXC16DCC14DCx, 3HPVSTETCOAhcx, FAOXC120100x, FAOXC2442246x, r0310, RE1517X, PROFVSCOAhc, r1449, FAOXC10DCC8DCx, HMR_3102, RE3247M, RE3086X, FAOXC184C164x, FAOXC16080x, FAOXC180x, HMR_3326, RE1519X, FAOXC6DCC4DCx, r1450, FAOXC260240x_1, ACOAO8p, RE2998M, FAOXC12DCC10DCx, FAOXC141C121x, FAOXC201C181x, HMR_1637, FAOXC2242046x, RE2994X, r1447, RE3626M, FAOXC10080x, HMR_3330}
# ACY1 is associated with reactions: {ACODA, RE2640C}
# ACO2 is associated with reactions: {ACONTm, r0426, r0317}
# ACO1 is associated with reactions: {ACONTm, ACONT, r0426, r0317}
# ACOX2 is associated with reactions: {RE3157X, ACOX22x, RE2985X, ACOX2x, RE2994X, RE2997X, RE3086X, RE3247X}
# ACP1 is associated with reactions: {ACP1_FMN, ACP1e}
# ACPP is associated with reactions: {NTD7l, NTD5l, LAPCOAl, NTD2l, NTD9l, ACP1_FMN, NTD4l, NADPPPS}
# ACP1 is associated with reactions: {ACP1_FMN, ACP1e, NADPPPS}
# ACP1 is associated with reactions: {ACP1_FMN, ACP1e}
# SLC25A20 is associated with reactions: {HMR_2685, OCD11CRNCACT, ARACHCRNt, DCSPTN1CRNt, TTDCRNt, LNELDCCRNt, HMR_2679, C6CRNtcx, HMR_2740, CRNCARtm, HMR_2772, r0995, HMR_2682, HMR_2753, HMR_2734, ELAIDCRNt, LNLNCGCRNt, PTDCACRNt, C4DCCACT, HMR_2688, HPDCACRNt, HMR_2764, C6DCCACT, HMR_2661, HMR_2715, HMR_2775, CARN1836Z9Z12Zt_m, SUBERCACT, C161CRN2t, C180CRNt, r2434, CLPNDCRNt, HMR_2737, HMR_2700, HMR_2624, C204CRNt, LNLNCACRNt, HMR_2644, TETTET6CRNt, CARN160t_m, CRNtim, C9BRxtc, OCTDECCACT, DLNLCGCRNt, C10DCCACT, HMR_2769, C4tmc, HMR_2670, CARN1819Zt_m, C161CRNt, HMR_2621, CARN140t_m, HMR_2757, HMR_2667, HMR_2718, r2437, HMR_2722, HMR_2695, TETPENT3CRNt, HMR_2691, PCRNtm, HMR_2652, ADRNCRNt, C4tcx, HMR_2727, HMR_2603, HMR_2703, CARN1829Z12Zt_m, HMR_2673, HMR_2712, ACRNtp, CARN180t_m, ACRNtm, C181CRNt, TMNDNCCRNt, HMR_2609, HMR_2731, STRDNCCRNt, FAOXC12DCTc, HMR_2634, HMR_2649, RTOTAL3CRNt, EICOSTETCRNt, LNLCCRNt, r2438, C160CRNt, HMR_2706, HMR_2676, HMR_2709, HMR_2760, TETPENT6CRNt}
# SLC16A7 is associated with reactions: {PHPYRte, D_LACt2, r1454, ACACt2, r1155, ACETONEt2, L_LACt2r, 2HBt2, PYRt2, PYRt2p, 2OBUTt}
# ACSS2 is associated with reactions: {r0319, ACS2, r0318, r0068, ACCOAL, r0097, ACS, r0220_1, r0221_1}
# ACSS2 is associated with reactions: {ACS2, ACS, ACCOAL}
# SLC16A3 is associated with reactions: {PHPYRte, 2HBt2, D_LACt2, PYRt2, ACETONEt2, L_LACt2r}
# SLC16A1 is associated with reactions: {BUTt2m, r2116, r2130, r2082, r2101, r2080, r2117, r2133, r2083, r2104, PHPYRte, r2081, r2118, r2091, r2106, r2084, 2HBt2, r2119, r2095, r2108, r2085, r2124, ACETONEt2m, r2097, r2111, r2086, r2127, r2098, r2113, r1454, r2087, r2128, r2099, r2114, r2088, r0954, r2129, ATVACIDMCTtu, r2102, r1155, r2115, r2089, D_LACtm, r2131, PYRt2, BUTt2r, r2103, L_LACtm, r2120, r2090, ACACt2m, r2132, BTNt2m, ACACt2, r2516, r2105, r2121, PYRt2m, r2092, r2107, r2122, r2093, D_LACt2, BTNt2i, r2109, L_LACt2r, r2123, r2094, 2HYOXPLCte, r2110, r2125, r2096, ACETONEt2, r2112, r2126, r2079, PYRt2p, r2100}
# SLC4A5 is associated with reactions: {2HCO3_NAt, 3HCO3_NAt}
# AACS is associated with reactions: {ACS2, ACS, AACOAT, r0321}
# SLC4A4 is associated with reactions: {2HCO3_NAt, 3HCO3_NAt}
# SLC4A5 is associated with reactions: {2HCO3_NAt, 3HCO3_NAt}
# ASMT is associated with reactions: {ACSRTNMT}
# SLC4A5 is associated with reactions: {2HCO3_NAt, 3HCO3_NAt}
# CYP2E1 is associated with reactions: {HMR_2029, HMR_0942, HMR_0946, 3OHACMPhr, HMR_2457, HMR_0950, ETOHMO, P4502E1, ACTLMO, HMR_0954, HMR_1927, RE2235R, ACTNMO}
# SLC4A5 is associated with reactions: {HCO3_2NAt, 2HCO3_NAt, 3HCO3_NAt}
# OGDH is associated with reactions: {AKGDm, 2OXOADOXm}
# ADA is associated with reactions: {ADA, ADAe, DADA, DADAe}
# PDHX is associated with reactions: {AKGDm, 2OXOADOXm, PDHm}
# DLD is associated with reactions: {HMR_6397, GCC2am, OIVD1m, GCCcm, OBDHm, PDHm, GCCbim, GCC2cm, OIVD3m, AKGDm, GCC2bim, 2OXOADOXm, OIVD2m, GCCam}
# SLC29A2 is associated with reactions: {URAt, DINt, HYXNt, THYMDt1, DGSNt, DCYTtm, GUAt, URIt, DCYTt, HMR_8476, DURIt, CSNt, CE2705t, ADNt, ADEt, CYTDt, THYMt, INSt, DADNt4, GSNt}
# OGDH is associated with reactions: {AKGDm, 2OXOADOXm, r0451}
# DLST is associated with reactions: {r0557, 2OXOADOXm, AKGDm}
# ADH1C is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, ALCD1, r0739, LCARS}
# AK4 is associated with reactions: {ADK1m}
# ADH5 is associated with reactions: {HMR_6633, ALCD22_D, 34DHOXPEGOX, ALCD22_L, FAOXOHMC10DC10c, ALCD21_D, LALDO, ALCD2x, FAOXOHC16C16DCc, ALCD1, FALDH, HMR_9804, r1378, FAOXOHC22C22DCc, HMR_1129, r0739, LCARS}
# AK2 is associated with reactions: {ADK1m, ADK1, DADK}
# ADH6 is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, ALCD1, r0739, LCARS}
# AK4 is associated with reactions: {ADK1m}
# ADH4 is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, ALCD1, r0739, LCARS}
# AK4 is associated with reactions: {ADK1m, DADK}
# ADH7 is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, ALCD1, r0739, LCARS}
# AK2 is associated with reactions: {ADK1m}
# ADH1A is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, ALCD1, r0739, LCARS}
# AK2 is associated with reactions: {ADK1m}
# ADH1B is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, ALCD1, r0739, LCARS}
# AK5 is associated with reactions: {CYTK3, CYTK4, ADKd, ADK1, ADK3}
# ADHFE1 is associated with reactions: {HMR_6633, 34DHOXPEGOX, ALCD22_D, ALCD22_L, HMR_1129, ALCD21_D, ALCD2x, RE3011M, ALCD1, LCARS}
# AK5 is associated with reactions: {CYTK3, CYTK4, DADK, ADKd, ADK1, ADK3}
# COMT is associated with reactions: {SALMCOM, 34DHPHAMT, DOPAMT}
# AK3 is associated with reactions: {ADK3m}
# COMT is associated with reactions: {SALMCOM, 34DHPHAMT, DOPAMT, HMR_6755}
# AMD1 is associated with reactions: {ADMDC}
# SLC16A10 is associated with reactions: {34DHPHEt, TYRt, PHEtec, TRPt}
# ALDH3B2 is associated with reactions: {ALDD19x_P, LCADi_D, r0757, 3MOX4HOXPGALDOX_NADP, ALDD19xr, GLACO, r0752, MACOXO, 3M4HDXPAC, r0754, 4HOXPACDOX_NADP, 4HALDD, r0756, 3MOX4HOXPGALDOX, ALDD2x, r0548, 34DHALDD, r0755, 34DHXMANDACOX_NADP, 34DHPLACOX_NADP, r0753, ALDD2y, r0546, GCALDD, LCADi}
# ADCY7 is associated with reactions: {ADNCYC}
# ALDH3A1 is associated with reactions: {ALDD19x_P, RE3346C, LCADi_D, r0757, 3MOX4HOXPGALDOX_NADP, ALDD19xr, RE3012C, GLACO, r0752, MACOXO, 3M4HDXPAC, r0754, 4HOXPACDOX_NADP, 4HALDD, r0756, 3MOX4HOXPGALDOX, 34DHXMANDACOX, RE3012R, ALDD2x, r0548, 34DHALDD, r0755, 34DHPLACOX_NADP, r0753, ALDD2y, r0546, GCALDD, LCADi}
# ADCY2 is associated with reactions: {ADNCYC}
# ALDH1A3 is associated with reactions: {ALDD19x_P, LCADi_D, 3MOX4HOXPGALDOX_NADP, ALDD19xr, GLACO, r0752, MACOXO, 3M4HDXPAC, r0754, 4HOXPACDOX_NADP, 4HALDD, r0756, 3MOX4HOXPGALDOX, 34DHXMANDACOX, ALDD2x, r0548, 34DHALDD, r0755, r0753, r0757, r0546, GCALDD, LCADi}
# ALDH3B1 is associated with reactions: {ALDD19x_P, LCADi_D, r0757, 3MOX4HOXPGALDOX_NADP, ALDD19xr, GLACO, r0752, MACOXO, 3M4HDXPAC, r0754, 4HOXPACDOX_NADP, 4HALDD, r0756, 3MOX4HOXPGALDOX, 34DHXMANDACOX, ALDD2x, r0548, 34DHALDD, r0755, 34DHXMANDACOX_NADP, 34DHPLACOX_NADP, r0753, ALDD2y, r0546, GCALDD, LCADi}
# ADCY8 is associated with reactions: {ADNCYC}
# ADCY5 is associated with reactions: {ADNCYC}
# HPD is associated with reactions: {34HPPOR, PPOR}
# ADCY9 is associated with reactions: {ADNCYC}
# ABAT is associated with reactions: {APAT2rm, ABTArm, r0483, 3AIBtm, 3AIBTm}
# ADCY3 is associated with reactions: {ADNCYC}
# ABAT is associated with reactions: {3AIBtm, APAT2rm, 3AIBTm, ABTArm}
# ADCY10 is associated with reactions: {ADNCYC}
# ADCY4 is associated with reactions: {ADNCYC}
# KDSR is associated with reactions: {3DSPHR}
# ADCY1 is associated with reactions: {ADNCYC}
# HAAO is associated with reactions: {3HAO}
# ADCY6 is associated with reactions: {ADNCYC}
# ECHDC2 is associated with reactions: {3HBCDm}
# AADAT is associated with reactions: {AATA, 3HKYNAKGAT, KYNAKGAT}
# ADCY6 is associated with reactions: {ADNCYC}
# AADAT is associated with reactions: {AATA, 3HKYNAKGAT, r0450, KYNAKGAT}
# SLC29A1 is associated with reactions: {DCYTtm, URIt, HMR_8476, CYTDtm, CE2705t, THYMDt1, ADNt, CYTDt, INSt, THYMDtm, ADNtm, GSNt}
# KYAT1 is associated with reactions: {3HKYNAKGAT, RE1233C, RE2349C, KYNAKGAT}
# DDC is associated with reactions: {3HLYTCL, HISDC, 5HLTDL, LTDCL, PHYCBOXL, TYRCBOX}
# MAOB is associated with reactions: {42A12BOOX, TYROXDAc, 3MOXTYROX, HMR_6747, MAOLNOR, TRYPTAOX, 5HOXINOXDA, MACOXO, PEAMNO, 41R1H2MAE12BOOX, APRTO2, 41R2A1H12BOOX}
# SLC28A1 is associated with reactions: {CYTDt4, ADNt4, URIt4, THMDt4}
# SLC28A3 is associated with reactions: {GSNt2, THMDt5, INSt2, THMDt4, ADNt2, HMR_6365, HMR_6364, ALLOP1tu, URIt5, HMR_6362, CYTDt5, r1043, r1044, ADNt4, CYTDt4, THMDt2, HMR_6363, URIt4, r2449, CYTDt2, GSNt5, URIt2, INSt5, ADNt5, r1045, GSNt4, r2447, HMR_6359, INSt4, ALLOP2tu}
# MAOA is associated with reactions: {42A12BOOX, TYROXDAc, 3MOXTYROX, HMR_6747, MAOLNOR, TRYPTAOX, 5HOXINOXDA, PEAMNO, 41R1H2MAE12BOOX, APRTO2, 41R2A1H12BOOX}
# SLC28A2 is associated with reactions: {URIt4, r2449, ALLOP1tu, ADNt4, INSt4, r1045, GSNt4}
# SLC28A1 is associated with reactions: {URIt4, THMDt4, r2447, ALLOP1tu, r1044, ADNt4, r1043, CYTDt4}
# SLC25A13 is associated with reactions: {3SALAASPm, GLUt2m, HMR_3864, ASPGLUm}
# SLC29A3 is associated with reactions: {THYMDtl, CYTDtl, Uritl, GSNtl, ADNtl}
# SLC25A12 is associated with reactions: {3SALAASPm, GLUt2m, HMR_3864, ASPGLUm}
# ATP6V0D2 is associated with reactions: {ATPasel_1}
# GAD2 is associated with reactions: {LCYSTCBOXL, GLUDC, 3SALACBOXL_cho}
# ATP6V0D1 is associated with reactions: {ATPasel_1}
# NUDT5 is associated with reactions: {ADPMAN, ADPRDP}
# GAD1 is associated with reactions: {3SALACBOXL_cho, LCYSTCBOXL, GLUDC, ASP1DC}
# CD38 is associated with reactions: {ADPRIBt, NADPNe, NADNe}
# GAD1 is associated with reactions: {3SALACBOXL_cho, LCYSTCBOXL, GLUDC, ASP1DC}
# CSAD is associated with reactions: {LCYSTCBOXL, 3SALACBOXL_cho}
# CPT1B is associated with reactions: {LNELDCCPT1, HMR_2739, C181CPT1, HMR_2669, STRDNCCPT1, C4OHc, C60CPT1, HMR_2768, C142OHc, HMR_2608, FAOXC12DCc, HMR_2666, C14OHc, C141CPT1, HMR_2687, C100CPT1, TTDCPT1, HMR_2690, C81CPT1, C226CPT1, HMR_2633, OCTDECCPT1, C10OHc, TETTET6CPT1, LNLNCACPT1, C8DCc, C16OHc, FAOXC3DC, ADRNCPT1, C10DCc, C101CPT1, C121CPT1, C18OHc, TMNDNCCPT1, CLPNDCPT1, C141OHc, LNLNCGCPT1, HMR_2602, C6DCc, FAOXC5C5DCc, C160CPT1, HMR_2651, HMR_2699, C180CPT1, HMR_2774, HMR_2705, C161OHc, HMR_2711, TETPENT3CPT1, FAOXC4C4DCc, C182OHc, C12OHc, FAOXC5OHc, HMR_2675, C161CPT12, C80CPT1, C120CPT1, C181OHc, HMR_2611, HMR_2684, HMR_2702, C102CPT1, C162OHc, HMR_2648, DCSPTN1CPT1, C204CPT1, OCD11COACPT1_1, ELAIDCPT1, EICOSTETCPT1, LNLCCPT1, TETPENT6CPT1, C16DCc, HMR_2620, HMR_2657, C51CPT1, C30CPT1, C161CPT1, HPDCACRNCPT1, HMR_2736, DLNLCGCPT1, HMR_2681, HMR_2733, HMR_2771, HMR_2708, HMR_2693, VACCCPT1, ARACHCPT1, RTOTAL3CRNCPT1, C40CPT1, C142CPT1, C50CPT1, PTDCACRNCPT1}
# ATP6V0B is associated with reactions: {ATPasel_1}
# GOT1 is associated with reactions: {ASPTA, CYSTA, TYRTA, 3SALATAi, PHETA1, LCYSTAT}
# ATP6V0A4 is associated with reactions: {ATPasel_1}
# CPT1A is associated with reactions: {LNELDCCPT1, HMR_2739, C181CPT1, HMR_2669, STRDNCCPT1, C4OHc, C60CPT1, HMR_2768, C142OHc, HMR_2608, FAOXC12DCc, HMR_2666, C14OHc, C141CPT1, HMR_2687, C100CPT1, TTDCPT1, HMR_2690, C81CPT1, C226CPT1, HMR_2633, OCTDECCPT1, C10OHc, TETTET6CPT1, LNLNCACPT1, C8DCc, C16OHc, FAOXC3DC, ADRNCPT1, C10DCc, C101CPT1, r0431_1, C121CPT1, C18OHc, TMNDNCCPT1, CLPNDCPT1, C141OHc, LNLNCGCPT1, HMR_2602, C6DCc, FAOXC5C5DCc, C160CPT1, r0432_1, HMR_2651, HMR_2699, C180CPT1, HMR_2774, HMR_2705, C161OHc, r0441, HMR_2711, TETPENT3CPT1, FAOXC4C4DCc, r0440, C182OHc, C12OHc, FAOXC5OHc, HMR_2675, C161CPT12, C80CPT1, C120CPT1, C160CPT2, C181OHc, r0434, HMR_2611, r0443, HMR_2684, HMR_2702, r0437, C102CPT1, C162OHc, HMR_2648, DCSPTN1CPT1, C204CPT1, r0444, OCD11COACPT1_1, ELAIDCPT1, EICOSTETCPT1, LNLCCPT1, TETPENT6CPT1, C16DCc, HMR_2620, HMR_2657, C51CPT1, C30CPT1, C161CPT1, HPDCACRNCPT1, HMR_2736, DLNLCGCPT1, HMR_2681, HMR_2733, HMR_2771, r0438, HMR_2708, HMR_2693, VACCCPT1, ARACHCPT1, r0433_1, RTOTAL3CRNCPT1, C40CPT1, C142CPT1, C50CPT1, PTDCACRNCPT1}
# GOT2 is associated with reactions: {TYRTAim, EHGLATm, 3SALATAim, EHGLAT2m, PHETA1m, ASPTAm}
# ALDH4A1 is associated with reactions: {GCALDDm, PHCDm, r0686, 4HGLSDm, P5CDm, LCADm, ALDD20xm, r0074}
# CPT1C is associated with reactions: {LNELDCCPT1, HMR_2739, C181CPT1, HMR_2669, STRDNCCPT1, C4OHc, C60CPT1, HMR_2768, C142OHc, HMR_2608, FAOXC12DCc, HMR_2666, C14OHc, C141CPT1, HMR_2687, C100CPT1, TTDCPT1, HMR_2690, C81CPT1, C226CPT1, HMR_2633, OCTDECCPT1, C10OHc, TETTET6CPT1, LNLNCACPT1, C8DCc, C16OHc, FAOXC3DC, ADRNCPT1, C10DCc, C101CPT1, C121CPT1, C18OHc, TMNDNCCPT1, CLPNDCPT1, C141OHc, LNLNCGCPT1, HMR_2602, C6DCc, FAOXC5C5DCc, C160CPT1, HMR_2651, HMR_2699, C180CPT1, HMR_2774, HMR_2705, C161OHc, HMR_2711, TETPENT3CPT1, FAOXC4C4DCc, C182OHc, C12OHc, FAOXC5OHc, HMR_2675, C161CPT12, C80CPT1, C120CPT1, C181OHc, HMR_2611, HMR_2684, HMR_2702, C102CPT1, C162OHc, HMR_2648, DCSPTN1CPT1, C204CPT1, OCD11COACPT1_1, ELAIDCPT1, EICOSTETCPT1, LNLCCPT1, TETPENT6CPT1, C16DCc, HMR_2620, HMR_2657, C51CPT1, C30CPT1, C161CPT1, HPDCACRNCPT1, HMR_2736, DLNLCGCPT1, HMR_2681, HMR_2733, HMR_2771, HMR_2708, HMR_2693, VACCCPT1, ARACHCPT1, RTOTAL3CRNCPT1, C40CPT1, C142CPT1, C50CPT1, PTDCACRNCPT1}
# ALDH4A1 is associated with reactions: {LCADm, GCALDDm, PHCDm, P5CDm, ALDD20xm, 4HGLSDm}
# TCIRG1 is associated with reactions: {ATPasel_1}
# SULT1A1 is associated with reactions: {TRIODTHYSULT, DOPASULT, TYMSULT, DOPASULT4, ESTSULT, 4NPHSULT}
# ATP6V0A1 is associated with reactions: {ATPasel_1}
# CPT1B is associated with reactions: {TMNDNCCPT1, C181CPT1, C160CPT1, DCSPTN1CPT1, TETTET6CPT1, C204CPT1, LNLNCACPT1, C180CPT1, ELAIDCPT1, STRDNCCPT1, EICOSTETCPT1, LNLCCPT1, TETPENT6CPT1, TETPENT3CPT1, ADRNCPT1, C161CPT1, HPDCACRNCPT1, C161CPT12, DLNLCGCPT1, ARACHCPT1, RTOTAL3CRNCPT1, C226CPT1, CLPNDCPT1, LNELDCCPT1, LNLNCGCPT1, PTDCACRNCPT1}
# SULT1A1 is associated with reactions: {TRIODTHYSULT, DOPASULT4, ACMPShc, ESTSULT, PCSF, DOPASULT, TYMSULT, 4NPHSULT}
# CPT1B is associated with reactions: {TMNDNCCPT1, LNELDCCPT1, C181CPT1, DCSPTN1CPT1, TETTET6CPT1, C204CPT1, LNLNCACPT1, C180CPT1, ELAIDCPT1, STRDNCCPT1, EICOSTETCPT1, LNLCCPT1, TETPENT6CPT1, TETPENT3CPT1, ADRNCPT1, C161CPT1, DLNLCGCPT1, ARACHCPT1, RTOTAL3CRNCPT1, C226CPT1, CLPNDCPT1, C161CPT12, LNLNCGCPT1, PTDCACRNCPT1}
# ATP6V1G3 is associated with reactions: {ATPasel_1}
# SULT1A3 is associated with reactions: {DOPASULT, TYMSULT, NRPPHRSULT, DOPASULT4, 4NPHSULT}
# CPT1B is associated with reactions: {TMNDNCCPT1, C181CPT1, C160CPT1, DCSPTN1CPT1, TETTET6CPT1, C204CPT1, LNLNCACPT1, C180CPT1, ELAIDCPT1, STRDNCCPT1, EICOSTETCPT1, LNLCCPT1, TETPENT6CPT1, TETPENT3CPT1, ADRNCPT1, C161CPT1, HPDCACRNCPT1, C161CPT12, DLNLCGCPT1, ARACHCPT1, C226CPT1, CLPNDCPT1, LNELDCCPT1, LNLNCGCPT1, PTDCACRNCPT1}
# ATP6V1A is associated with reactions: {ATPasel_1}
# SULT1A1 is associated with reactions: {TRIODTHYSULT, DOPASULT, TYMSULT, DOPASULT4, ESTSULT, 4NPHSULT}
# CPT2 is associated with reactions: {TTDCPT2, LNLCCPT2, HMR_2677, HMR_2635, HMR_2613, HPDCACRNCPT2, LNLNCGCPT2, ARACHCPT2, C161CPT22, C204CPT2, HMR_2659, DLNLCGCPT2, HMR_2735, ELAIDCPT2, PTDCACRNCPT2, C180CPT2, HMR_2741, HMR_2683, HMR_2650, r0431_1, HMR_2697, HMR_2692, C181CPT2, HMR_2738, LNELDCCPT2, HMR_2710, r0432_1, TMNDNCCPT2, HMR_2773, CLPNDCPT2, HMR_2604, ADRNCPT2, r0441, C161CPT2, HMR_2776, RTOTAL3CRNCPT2, r0440, OCTDECCPT2, VACCCPT2, HMR_2689, LNLNCACPT2, HMR_2701, C226CPT2, r0434, C160CPT2, DCSPTN1CPT2, r0443, r0437, HMR_2686, HMR_2610, HMR_2704, HMR_2653, r0444, HMR_2622, STRDNCCPT2, TETTET6CPT2, EICOSTETCPT2, OCD11CRNCPT2_1, HMR_2770, r0438, HMR_2668, HMR_2671, HMR_2713, r0433_1, C4CRNCPT2, TETPENT6CPT2, TETPENT3CPT2, HMR_2707}
# SULT1A2 is associated with reactions: {DOPASULT, 4NPHSULT}
# PAPSS2 is associated with reactions: {ADSK, SADT}
# ATP6V0E1 is associated with reactions: {ATPasel_1}
# SULT1A1 is associated with reactions: {TRIODTHYSULT, DOPASULT, TYMSULT, DOPASULT4, ESTSULT, 4NPHSULT}
# SULT1A3 is associated with reactions: {DOPASULT, TYMSULT, NRPPHRSULT, DOPASULT4, 4NPHSULT}
# PAPSS1 is associated with reactions: {ADSK, SADT}
# SULT1A1 is associated with reactions: {TRIODTHYSULT, DOPASULT, TYMSULT, DOPASULT4, ESTSULT, 4NPHSULT}
# ADSL is associated with reactions: {ADSL2r, ADSL1r}
# ATP6V1G1 is associated with reactions: {ATPasel_1}
# SULT1A2 is associated with reactions: {DOPASULT, 4NPHSULT}
# ABCC1 is associated with reactions: {SPHMYLN181221_hs_ATPt, FOLABCCte, SPHMYLN180241_hs_ATPt, DOPA4GLCURt, CE1447te, CE5026t, SPHMYLN18117_hs_ATPt, SPHMYLN18123_hs_ATPt, SPHS1Pt2e, SPHMYLN181161_hs_ATPt, BILGLCURte, SPHMYLN181181_hs_ATPt, r2505, TSTSTERONEGLCte, CE7096te, AHANDROSTANGLCte, CE7085te, ESTRIOLGLCte, MLTHFte1, SPHMYLN1824_hs_ATPt, SPHMYLN18120_hs_ATPt, 5ADTSTSTERONEGLCte, ANDRSTRNGLCte, CE7090te, SPHMYLN1825_hs_ATPt, SPHMYLN181201_hs_ATPt, DIGALSGALSIDEATPte, SPHMYLN18122_hs_ATPt, SPHMYLN18121_hs_ATPt, CE4877te, SPHMYLN_HsATPte, CE5025t, DOPA3GLCURt, HMR_1897, SPHMYLN18116_hs_ATPt, SPHMYLN18115_hs_ATPt, CE2006te, BILDGLCURte, SPHMYLN18114_hs_ATPt, SPHMYLN18118_hs_ATPt}
# ATP6V1E1 is associated with reactions: {ATPasel_1}
# ADSL is associated with reactions: {ADSL2r, ADSL1r}
# SULT2A1 is associated with reactions: {TDCASULT, TSTSTERONESULT, HC02198c, PRGNLONESULT, DHEASULT, GCDCASULT, UDCASULT, DCASULT, GDCASULT, TCASULT, LCASULT, TCDCASULT, TUDCASULT, CASULT, 5ADTSTSTERONESULT, GUDCASULT, HC02197c, HC02220c, GCASULT}
# SLC19A1 is associated with reactions: {5FTHFt2_1, FOLt2_1, 5MTHFt2_1, MLTHFte2, THMTPt_1, THMMPt4_1, THFt2_1}
# SLC19A1 is associated with reactions: {FOLt2_1, 5MTHFt2_1, MLTHFte2, THMMPt4_1, THFt2_1, 5FTHFt2_1, THMTPt_1, APRGSTRNt1e}
# B3GNTL1 is associated with reactions: {AG13T17g, AG13T18g, AG13T16g, AG13T2g, AG13T3g, AG13T1g, HMR_0765}
# ATP6V1C1 is associated with reactions: {ATPasel_1}
# AOX1 is associated with reactions: {ALLOPOXDhep, PYDXDH, 5HOXINDACTO2OX}
# B3GNT2 is associated with reactions: {AG13T18g, AG13T16g, AG13T17g, B3GNT12g, AG13T3g, AG13T1g, AG13T2g}
# SLC18A2 is associated with reactions: {DOPAVESSEC_1, 5HTRPVESSEC_1, HISTAVESSEC_1, NRPPHRVESSEC_1, ADRNLPVESSEC_1}
# SLC18A1 is associated with reactions: {DOPAVESSEC_1, 5HTRPVESSEC_1, HISTAVESSEC_1, NRPPHRVESSEC_1, ADRNLPVESSEC_1}
# B3GNT3 is associated with reactions: {B3GNT314g, AG13T16g, B3GNT315g, HMR_0889, AG13T3g, B3GNT34g, B3GNT36g, B3GNT32g, B3GNT310g, B3GNT31g, AG13T1g, B3GNT39g, AG13T18g, B3GNT312g, B3GNT33g, B3GNT313g, HMR_0765, B3GNT311g, AG13T2g, B3GNT37g, AG13T17g, B3GNT35g}
# ATP6V1D is associated with reactions: {ATPasel_1}
# FOLR1 is associated with reactions: {5MTHFt}
# ATP6V1E2 is associated with reactions: {ATPasel_1}
# ATP6V1G2 is associated with reactions: {ATPasel_1}
# B3GNT8 is associated with reactions: {AG13T17g, AG13T18g, AG13T16g, AG13T2g, AG13T3g, AG13T1g, HMR_0765}
# FOLR3 is associated with reactions: {r0963, MLTHFte3, 5MTHFt}
# B3GNT2 is associated with reactions: {AG13T18g, AG13T16g, HMR_0889, AG13T3g, HMR_0765, B3GNT11g, AG13T2g, AG13T17g, B3GNT12g, AG13T1g}
# B3GNT8 is associated with reactions: {AG13T18g, AG13T16g, AG13T17g, AG13T3g, AG13T1g, AG13T2g}
# ATP6V0A4 is associated with reactions: {ATPasel_1}
# ATP6V1H is associated with reactions: {ATPasel_1}
# FOLR1 is associated with reactions: {5MTHFt}
# TCIRG1 is associated with reactions: {ATPasel_1}
# ATP6V1H is associated with reactions: {ATPasel_1}
# B4GAT1 is associated with reactions: {AG13T18g, AG13T16g, AG13T17g, HMR_0889, AG13T3g, AG13T1g, AG13T2g}
# FOLR1 is associated with reactions: {5MTHFt}
# B3GNT7 is associated with reactions: {AG13T17g, AG13T18g, AG13T16g, AG13T2g, AG13T3g, AG13T1g, HMR_0765}
# ATP6V1F is associated with reactions: {ATPasel_1}
# FOLR1 is associated with reactions: {r0963, MLTHFte3, 5MTHFt}
# FOLR1 is associated with reactions: {5MTHFt}
# FOLR1 is associated with reactions: {5MTHFt}
# B3GNT4 is associated with reactions: {AG13T18g, AG13T16g, HMR_0889, AG13T3g, HMR_0765, AG13T2g, AG13T17g, AG13T1g}
# MAN2B1 is associated with reactions: {A_MANASEly}
# ENTPD2 is associated with reactions: {ATPH1e, ATPH2e}
# AGMAT is associated with reactions: {AGMTm}
# A4GALT is associated with reactions: {A4GALTg, A4GALTc}
# A4GNT is associated with reactions: {A4GNT1g, A4GNT2g, HMR_0765}
# ENTPD2 is associated with reactions: {ATPH1e, ATPH2e}
# ABO is associated with reactions: {ABO5g, ABO7g, ABO1g, ABO6g, ABO4g, HMR_0867, ABO9g, ABO8g, ABO3g, ABO2g, HMR_0868}
# ENTPD1 is associated with reactions: {NDP10ex, r0497, ATPH2e, NDP3ex, NDP1, r0149, r0139, ITPH2, r0494, ATPH1e, NDP8ex, NDP7ex, NTP3e}
# SLC36A1 is associated with reactions: {ABUTt2r, BALAt2r, PROt2r, ABUTt2rL, GLYt2r, DALAt2r, PRODt2r, ALAt2r, SERt2r, TAUPAT1c}
# ENTPD5 is associated with reactions: {NDP7er, ATPH1e, ATPH2e}
# AGPAT4 is associated with reactions: {HMR_0593, AGPAT1_1}
# SLC6A13 is associated with reactions: {ABUTt4_2_r, HMR_9613}
# GPAT4 is associated with reactions: {AGPAT1_1}
# MBOAT2 is associated with reactions: {HMR_0593, AGPAT1_1, GPAM_hs_1}
# ENTPD3 is associated with reactions: {NDP10ex, r0497, ATPH2e, NDP3ex, NDP1, r0149, r0139, ITPH2, r0494, ATPH1e, NDP8ex, NDP7ex, NTP3e}
# ENTPD6 is associated with reactions: {ATPH1e, ATPH2e}
# SLC6A12 is associated with reactions: {GLYBt4_2_r, HMR_9603, HMR_9602, GABABGTtc, HMR_9604, ABUTt4_2_r, BETBGTtc}
# AGPAT3 is associated with reactions: {HMR_0593, AGPAT1_1}
# AGPAT2 is associated with reactions: {HMR_0593, AGPAT1_1}
# AGPAT5 is associated with reactions: {HMR_0593, AGPAT1_1}
# AGPAT1 is associated with reactions: {HMR_0593, AGPAT1_1}
# SLC6A1 is associated with reactions: {ABUTt4_2_r, HMR_9613}
# SLC6A11 is associated with reactions: {ABUTt4_2_r, HMR_9613}
# AGPAT3 is associated with reactions: {AGPAT1_1}
# ACAA2 is associated with reactions: {HMR_3426, RE1531M, RE3189M, FAOXC6C4m, HMR_3406, HMR_3451, HMR_3424, HMR_3233, HMR_3414, RE3190M, HMR_3431, HMR_3422, HMR_3409, FAOXC121C101m, ACACT6m, HMR_3221, r0732, ACACT5m, FAOXC11C9m, FAOXC7C5m, HMR_3229, HMR_3427, RE1534M, HMR_3237, HMR_3185, RE3191M, HMR_3413, HMR_3201, FAOXC123C102m, FAOXC4020m, FAOXC81C61m, HMR_3181, r0287, HMR_3429, RE1532M, FAOXC101C8m, RE3006M, FAOXTC122TC101m, HMR_3189, HMR_9719, ACACT10m, FAOXC120100m, HMR_3423, HMR_3408, HMR_3425, HMR_3455, HMR_3432, HMR_3177, HMR_3407, r0698, FAOXC122C101m, HMR_3421, HMR_3110, HMR_3243, HMR_3205, FAOXC10080m, FAOXC61C4m, HMR_3411, HMR_3428, KAT180_m, HMR_3114, ACACT7m, HMR_3173, HMR_3416, FAOXC9C7m, HMR_3398, FAOXC8C6m, FAOXC5C3x, HMR_3433, RE1533M, HMR_3247, HMR_3193, ACACT4m, FAOXC102C81m, HMR_3225, HMR_3197, r1481}
# ACAT1 is associated with reactions: {ACACT1m, ACACT10m, 2M3OVCOAm}
# ETNPPL is associated with reactions: {AGTim, r0186}
# ENTPD8 is associated with reactions: {NDP10ex, r0497, ATPH2e, NDP3ex, NDP1, r0149, r0139, ITPH2, r0494, NDP8ex, NDP7ex, NTP3e}
# HADHB is associated with reactions: {HMR_3426, RE1531M, RE3189M, HMR_3406, RE3194M, HMR_3451, FAOXC162C142m, HMR_3424, HMR_3233, RE3177M, FAOXC170150m, HMR_3414, RE3190M, HMR_3431, HMR_3422, HMR_3409, RE3192M, ACACT6m, RE3179M, HMR_3221, r0732, RE1523M, FAOXC163C143m, RE1521M, ACACT5m, HMR_3229, FAOXC185C164m, RE1534M, FAOXC143C123m, FAOXC182C162m, FAOXC204C184m, HMR_3185, HMR_3237, RE3191M, FAOXC13C11m, FAOXTC162TC142m, HMR_3413, FAOXC163GC142m, FAOXC183C163Gm, 3HPVSTETCOAhcm, HMR_3201, RE3178M, RE3004M, FAOXC184C164m, HMR_3181, r0287, RE0512M, HMR_3429, RE1532M, FAOXC181C161m, RE3006M, FAOXC225C204m, FAOXC226C205m, HMR_3189, HMR_9719, ACACT10m, FAOXTC182TC162m, ECOAH1m, HMR_3423, HMR_3408, FAOXC184C163m, FAOXC183C163m, ECOAH12m, HMR_3425, FAOXC164C143m, HMR_3455, HMR_3432, FAOXC161C141m, HMR_3177, FAOXC205C185m, HMR_3407, r0698, FAOXC140120m, ECOAH9m, r1481, HMR_3421, HMR_3110, FAOXC142C122m, FAOXC160140m, HMR_3243, FAOXTC142TC122m, HMR_3205, FAOXC15C13m, HMR_3411, ACACT1m, HMR_3428, RE3193M, KAT180_m, HMR_3114, ACACT7m, HMR_3173, HMR_3416, HACD1m, FAOXC141C121m, HMR_3398, HMR_3247, HMR_3433, RE1533M, HMR_3193, ACACT4m, HMR_3225, HMR_3197, RE1522M, RE1520M, HMR_3427}
# SLC25A5 is associated with reactions: {ATPtm}
# SLC25A6 is associated with reactions: {ATPtm, r0801}
# AGXT2 is associated with reactions: {AGTim, D3AIBTm}
# HADHA is associated with reactions: {HMR_3424, HMR_3431, RE3192M, FAOXC161C161OHm, HMR_3187, FAOXC162C162OHm, FAOXC182C182OHm, HMR_3188, FAOXC185C164m, r0714_1, FAOXC143C123m, HMR_3200, HMR_3113, FAOXC183C163Gm, 3HPVSTETCOAhcm, RE3178M, r1474, HMR_3203, HMR_3429, r0715, RE1532M, FAOXC18C18OHm, HMR_3172, FAOXC226C205m, HMR_3175, HMR_3450, HMR_9719, FAOXC16C16OHm, HMR_3408, FAOXC184C163m, HACD6p, HMR_3204, FAOXC164C143m, HMR_3432, FAOXC161C141m, HMR_3177, HMR_3196, FAOXC140120m, r0716_1, r0720_1, FAOXTC142TC122m, HMR_3205, FAOXC15C13m, HACD5m, RE3193M, HMR_3114, FAOXC14C14OHm, r0717, HACD1m, HMR_3398, HMR_3433, RE1533M, HACD4m, HMR_3232, HMR_3225, HMR_3197, HACD6m, HMR_3449, HMR_3427, HMR_1651, HMR_3426, RE1531M, HMR_3231, RE3189M, HACD4p, HMR_3176, HMR_3406, RE3194M, HMR_3451, FAOXC162C142m, r0721, HMR_3233, RE3177M, HMR_3179, HMR_3220, FAOXC170150m, HMR_3414, RE3190M, HMR_3219, ECOAH4m, HMR_3184, HMR_3422, HMR_3409, HACD5p, HMR_3235, RE3179M, HMR_3180, HMR_3221, HMR_3236, RE1523M, FAOXC163C143m, RE1521M, HMR_3199, HMR_3229, FAOXC181C181OHm, HMR_3171, r0730, HMR_3117, RE1534M, FAOXC182C162m, FAOXC204C184m, HMR_3185, HMR_3237, RE3191M, FAOXC13C11m, FAOXTC162TC142m, HMR_3413, r0733, FAOXC163GC142m, HMR_3201, HMR_3454, FAOXC141C141OHm, ECOAH4p, HMR_3242, RE3004M, FAOXC184C164m, HMR_3181, RE0512M, HMR_3116, FAOXC181C161m, r0731, RE3006M, HMR_3108, FAOXC225C204m, HMR_3245, HMR_3189, ECOAH5m, ECOAH1m, FAOXTC182TC162m, HMR_3109, HMR_3246, HMR_3423, ECOAH12m, FAOXC183C163m, r0734, HMR_3425, HMR_3224, HMR_3455, FAOXC205C185m, HMR_3407, HMR_3191, ECOAH9m, HMR_3421, HMR_3110, ECOAH5p, FAOXC142C122m, FAOXC160140m, HMR_3243, HMR_3192, HMR_3411, HMR_3241, ACACT1m, HMR_3428, HMR_3453, HMR_3112, KAT180_m, HMR_3183, r0669, HMR_3173, HMR_3416, FAOXC141C121m, HMR_3247, HMR_3223, HMR_3193, HMR_3195, RE1522M, RE1520M, FAOXC142C142OHm}
# AGXT is associated with reactions: {AGTix, SPTix, SPTc}
# SLC25A4 is associated with reactions: {ATPtm}
# ACAT2 is associated with reactions: {ACACT1x, ACACT1r}
# ACAA1 is associated with reactions: {HMR_3426, ACACT6p, HMR_3345, FAOXC2051843x, HMR_3406, ACACT9p, HMR_3424, FAOXC225C204x, ACACT5p, ACACT7p, FAOXC11BRC9BRx, FAOXC183806x, HMR_3414, HMR_3431, FAOXC8C6x, PEROXx, HMR_3409, RE1531X, HMR_3422, FAOXC142C122x, RE3158X, ACACT6m, r0732, FAOXC160140x, FAOXC2252053x, FAOXC240200x_1, ACACT5m, RE1533X, FAOXC22C20x, HMR_3097, FAOXC161C141x, HMR_1653, HMR_3337, FAOXC2452253x, FAOXC2251836x, DEOXFVShc, FAOXC221C201x, HMR_3413, FAOXC200180x, HMR_3341, FAOXC121C10x, FAOXC18480x, HMR_3353, FAOXC6C4x, FAOXC15BRC13BRx, FAOXC81C61x, r0287, FAOXC241C221x, HMR_3429, HMR_3333, RE2989X, FAOXC143C123x, FAOXC205C184x, FAOXC8DCC6DCx, FAOXC2452256x, FAOXC123C102x, HMR_3101, RE1534X, HMR_3065, HMR_9719, HMR_3423, FAOXC101C8x, HMR_3408, FAOXC14DCC12DCx, FAOXC241181x, HMR_3425, HMR_3432, FAOXC24C22x, HMR_3073, RE1532X, HMR_3407, FAOXC164C143x, r0698, FAOXC181C161x, FAOXC13BRC11BRx, r1481, FAOXC246226x, HMR_3421, FAOXC102C81x, FAOXC226205x, 3HPVSTETCOAhcx, FAOXC16DCC14DCx, FAOXC120100x, HMR_3411, FAOXC2442246x, FAOXC163C142x, HMR_3428, FAOXC184C163x, PROFVSCOAhc, RE2988X, FAOXC10DCC8DCx, HMR_3069, ACACT8p, FAOXC184C164x, FOAXC122C101x, ACACT7m, FAOXC16080x, FAOXC180x, HMR_3416, HMR_3398, FAOXC6DCC4DCx, HMR_3433, FAOXC61C4x, FAOXC260240x_1, FAOXC12DCC10DCx, ACACT4m, HMR_3505, FAOXC201C181x, FAOXC141C121x, ACACT4p, HMR_3329, HMR_3349, FAOXC2242046x, FAOXC140120x, FAOXC10080x, HMR_3427}
# ACACB is associated with reactions: {ACCOACrm, ACCOAC}
# SLC33A1 is associated with reactions: {GAO2, GAO1, ACCOAgt, GAO1g, GAO2g, ACCOAtr}
# MANBA is associated with reactions: {B_MANNASEly}
# HEXA is associated with reactions: {NACHEX27ly, NACHEX16ly, NACHEXA4ly, HMR_0828, NACHEX2ly, NACHEX18ly, HEXA2l, NACHEX11ly, NACHEXA10ly, NACHEX3ly, r0013, NACHEX17ly, NACHEXA20ly, HEXA3e, NACHEXA22ly, NACHEX4ly, NACHEXA5ly, NACHEX6ly, HMR_0808, NACHEXA12ly, NACHEX1ly, NACHEX12ly, NACHEXA16ly, NACHEXA21ly, NACHEX21ly, NACHEXA6ly, NACHEXA7ly, NACHEX20ly, NACHEXA14ly, NACHEXA13ly, NACHEX22ly, NACHEXA17ly, NACHEXA2ly, HEXAHBl, NACHEXA11ly, NACHEXA8ly, NACHEX7ly, NACHEXA9ly, NACHEX25ly, HMR_0821, NACHEX23ly, NACHEX14ly, NACHEXA15ly, NACHEXA19ly, NACHEXA3ly, NACHEX8ly, NACHEX26ly, AHEXASE2ly, HEXA1l, AHEXASEly, HMR_0807, NACHEX19ly, NACHEX24ly, NACHEX13ly, NACHEX15ly, NACHEX10ly, NACHEX5ly, NACHEXA18ly, HMR_0836, NACHEX9ly, NACHEXA1ly}
# HEXB is associated with reactions: {NACHEX27ly, NACHEX16ly, NACHEXA4ly, HMR_0828, NACHEX2ly, NACHEX18ly, HEXA2l, NACHEX11ly, NACHEXA10ly, NACHEX3ly, r0013, NACHEX17ly, NACHEXA20ly, HEXA3e, NACHEXA22ly, NACHEX4ly, NACHEXA5ly, NACHEX6ly, HMR_0808, NACHEXA12ly, NACHEX1ly, NACHEX12ly, NACHEXA16ly, NACHEXA21ly, NACHEX21ly, NACHEXA6ly, NACHEXA7ly, NACHEX20ly, NACHEXA14ly, NACHEXA13ly, NACHEX22ly, NACHEXA17ly, NACHEXA2ly, HEXAHBl, NACHEXA11ly, NACHEXA8ly, NACHEX7ly, NACHEXA9ly, NACHEX25ly, HMR_0821, NACHEX23ly, NACHEX14ly, NACHEXA15ly, NACHEXA19ly, NACHEXA3ly, NACHEX8ly, NACHEX26ly, AHEXASE2ly, HEXA1l, AHEXASEly, HMR_0807, NACHEX19ly, NACHEX24ly, NACHEX13ly, NACHEX15ly, NACHEX10ly, NACHEX5ly, NACHEXA18ly, HMR_0836, NACHEX9ly, NACHEXA1ly}
# ACSS3 is associated with reactions: {r0220_1, r0221_1, ACCOALm, r0318, r0319}
# PAICS is associated with reactions: {AIRCr, PRASCSi}
# B3GALNT1 is associated with reactions: {HMR_0805, B3GALT3g, HMR_0806}
# ACSS1 is associated with reactions: {ACCOALm, r0319, r0318, r0068, r0097, r0220_1, r0221_1, ACSm}
# GNPNAT1 is associated with reactions: {ACGAM6PS}
# B3GALNT1 is associated with reactions: {B3GALT3g}
# B3GALNT1 is associated with reactions: {B3GALT3g}
# NAGK is associated with reactions: {AMANK, ACGAMK}
# B3GALNT1 is associated with reactions: {B3GALT3g}
# PGM3 is associated with reactions: {ACGAMPM}
# B3GALT4 is associated with reactions: {HMR_0816, B3GALT44g, B3GALT41g, HMR_0843, B3GALT43g, B3GALT42g, HMR_0829}
# PIGL is associated with reactions: {ACGPID}
# B3GALT5 is associated with reactions: {B3GALT5g, HMR_0860, HMR_0765}
# NAGS is associated with reactions: {ACGSm, RE2030M, RE2223M}
# B3GALT5 is associated with reactions: {B3GALT5g}
# ACHE is associated with reactions: {ACHEe}
# B3GALT5 is associated with reactions: {B3GALT5g}
# ACHE is associated with reactions: {ACHEe, HMR_0641}
# B3GALT5 is associated with reactions: {B3GALT5g}
# SLC18A3 is associated with reactions: {ACHVESSEC_1}
# B3GALT5 is associated with reactions: {B3GALT5g}
# B3GNT5 is associated with reactions: {HMR_0765, HMR_0859, B3GNT51g}
# ACLY is associated with reactions: {ACITL}
# BAAT is associated with reactions: {FACOAE140, HMR_0328, HMR_0390, BAAT5x, HMR_0302, HMR_0374, HMR_0276, HMR_0201, FACOAE120, RE0578C, FACOAE180, RE1835C, FACOAE1836Z9Z12Z, RE0579C_1, HMR_0362, FACOAE1829Z12Z, RE1846C, HMR_0354, HMR_0234, RE1834C, HMR_0193, BAAT2x, HMR_0290, HMR_0370, HMR_0210, HC02196c, BAAT4x_cho, RE2637C, RE1845C, ACChex, BAAT1x, HMR_0410, HMR_0434, HMR_0438, HMR_0386, HMR_0214, r0797, RE2649C, HMR_0366, HMR_0256, HMR_0242, HMR_0406, RE2637X, BAAT3x, FACOAE161, HMR_0268, HMR_0394, HMR_0306, HMR_0310, HMR_0422, HMR_0414, RE1834X, HMR_0280, HMR_0358, HC02195c, FACOAE1839Z12Z15Z, HMR_0272, r0629, HMR_0260, HMR_0324, RE2638C, HMR_0430, HMR_0298, HMR_0382, HMR_0418, HMR_0238, HMR_0246, HMR_0346, HMR_0426, HMR_0206, r0630, HMR_0378, RE0577C}
# HLCS is associated with reactions: {BACCL, BACCLm, BTNPLm, BTNPL}
# ACLY is associated with reactions: {ACITL}
# NANS is associated with reactions: {ACNAM9PL2, ACNAM9PL}
# SLC32A1 is associated with reactions: {GABAVESSEC_1, GLYVESSEC_1, BALAVECSEC_1}
# SLC17A5 is associated with reactions: {ACNAMlt, GLCURtly, IDOURtly}
# ACP5 is associated with reactions: {NTD7l, NTD5l, LAPCOAl, NTD2l, NTD9l, ACP1_FMN, NTD4l, NADPPPS, ACNAMPH}
# BBOX1 is associated with reactions: {BBHOX}
# ACP6 is associated with reactions: {NTD7l, NTD5l, LAPCOAl, NTD2l, NTD9l, ACP1_FMN, NTD4l, NADPPPS, ACNAMPH}
# BCO1 is associated with reactions: {BCDO}
# NANP is associated with reactions: {ACNAMPH}
# BDH1 is associated with reactions: {BDHm}
# ACADSB is associated with reactions: {r0603, ACOAD10m, HMR_3202, ACOAD1fm, RE3185M, ACOADH60_m, RE3186M}
# BDH1 is associated with reactions: {BDHm}
# ACADM is associated with reactions: {HMR_3426, HMR_3244, FAOXC6C4m, HMR_3406, HMR_3424, HMR_3414, FAOXC183806m, FAOXC226, HMR_3431, ACOAD9m, HMR_3409, HMR_3198, HMR_3422, FAOXC121C101m, HMR_3448, FAOXC204184m, HMR_3111, HMR_3452, HMR_3128, FAOXC11C9m, FAOXC18480m, FAOXC7C5m, FAOXC1811602m_1, FAOXC140, HMR_3115, ACOADH100_m, FAOXC2252053m, HMR_3413, HMR_3234, HMR_3107, HMR_3170, FAOXC81C61m, FAOXTC101TC102m, FAOXC2051843m, FAOXC102C103m, HMR_3222, FAOXC2242046m, r0603, ACOADH160_m, HMR_3429, FAOXC2251836m, HMR_3194, HMR_9719, FAOXC120100m, HMR_3423, HMR_3408, HMR_3425, FAOXC10C10OHm, HMR_3240, FAOXC161802m, HMR_3432, HMR_3190, HMR_3182, HMR_3522, HMR_3407, ACOADH120_m, ACOAD10m, r0655, HMR_3174, FAOXC182806m, HMR_3421, FAOXC183803m, FAOXC204, r0310, FAOXC10080m, RE3185M, ACOAD1fm, HMR_3411, FAOXC16080m, HMR_3456, HMR_3428, FAOXC16180m, FAOXC1811601m, FAOXC12C12OHm, FAOXC11, FAOXC150m, FAOXC170m, HMR_3230, HMR_3218, HMR_3416, HMR_3149, FAOXC9C7m, HMR_3398, FAOXC200180m, FAOXC80, HMR_3433, HMR_3178, FAOXC8C6m, RE3186M, FAOXC160, FAOXC1811603m, FAOXC2031836m, FAOXC180, HMR_3186, FAOXC18280m, FAOXC101C102m, HMR_3427, FAOXC226205m}
# BDH1 is associated with reactions: {BDHm}
# ACAD11 is associated with reactions: {ACOAD1fm}
# BHMT2 is associated with reactions: {BHMT}
# ACAD10 is associated with reactions: {ACOAD1fm}
# BHMT is associated with reactions: {BHMT}
# ACAD8 is associated with reactions: {ACOAD9m, ACOAD1fm}
# SLCO1B1 is associated with reactions: {DHEASt, TDCA3St, r2272, r2293, r2274, 2HATVLACthc, r2289, r2294, BILIRUBt2, ICDCHOLt, UDCA3St, r2225, 3DHDCAt, r2279, r2248, GCHOLAt, UDCHOLt, SMVthep, r2249, r2297, 3ISPVSthc, CRVSthc, r2280, r2232, C05769te3, r2250, r2299, ESTRADIOLGLCt, r2281, BILDGLCURt, C05770te4, r2234, 3DHLCAt, r2255, r2300, r2284, r2235, r2256, r2219, 3DHCDCHOLt, r2285, TUDCA3St, GDCA3St, r2240, r2257, r2301, r2226, r2286, r2307, r2241, HC02220t, THYOCHOLt, r2258, r2227, CHOLATEt, r2287, r2243, 6EPVSthc, 4HATVACIDthc, r2260, r2228, r2288, r2251, r2198, ATVLACThc, r2264, r2229, FOLOATPtc, r2290, r2252, r2200, r2265, r2230, ISOCHOLt, r2291, 3DHCHOLt, r2253, r2266, r2231, 7DHCDCHOLt, r2292, r2254, COPROSTt, LCA3St, r2268, 4HATVLACthc, r2233, GCDCA3St, r2295, r2259, UCHOLt, r2273, r2236, r2296, CA3St, r2261, r2275, r2237, r2298, r2199, r2262, r2276, r2238, r2302, r2201, LEUKTRC4t, r2263, TCA3St, r2277, r2239, 7DHCHOLt, r2303, r2202, r2267, GCA3St, r2218, 12DHCHOLt, TCHOLAt, r2278, TCDCA3St, r2242, r2304, HYOCHOLt, r2269, BILGLCURt, r2220, 2HATVACIDthc, THYOXt, 35DHPVSthc, r2282, r2244, TRIODTHYt, r2305, GUDCA3St, r2222, r2270, ESTRONESt, DCA3St, r2221, r2283, r2245, r2224, r2247, 3HPVSthc, r2306, r2223, r2271, r2246}
# ACAD9 is associated with reactions: {HMR_3426, HMR_3429, HMR_3244, HMR_3406, HMR_3424, HMR_3194, HMR_9719, HMR_3423, HMR_3408, HMR_3414, HMR_3425, HMR_3431, HMR_3422, HMR_3409, HMR_3198, HMR_3240, HMR_3190, HMR_3432, HMR_3448, HMR_3182, HMR_3407, ACOADH120_m, HMR_3174, HMR_3111, HMR_3421, HMR_3452, HMR_3128, ACOAD1fm, HMR_3411, HMR_3456, HMR_3428, r0706, HMR_3115, HMR_3230, HMR_3218, ACOADH100_m, HMR_3416, HMR_3149, HMR_3413, HMR_3234, HMR_3398, HMR_3178, HMR_3433, HMR_3107, HMR_3170, HMR_3186, HMR_3427, HMR_3222, ACOADH160_m}
# ABCC2 is associated with reactions: {THYOCHOLabc, GCA3Sabc, UCHOLabc, C05770te, FOLABCCte, TRIPVSteb, ICDCHOLabc, 7HPVSteb, LCA3Sabc, HC02220te, PVSGLUCteb, 56DHPVSteb, 4HATVLACteb, TDCA3Sabc, 2HATVACIDteb, LCA24Gte, DCA3Sabc, UDCA3Sabc, HDCA6Gte, C05769te, CA3Sabc, 2HATVLACteb, GDCA3Sabc, 7DHCDCHOLabc, 3ISPVSteb, HC02194te, TCA3Sabc, 6EPSteb, MLTHFte1, 56EPPVSteb, CA24Gte, CDCA3Gte, GCDCA3Sabc, r0993, 3HPVSTETteb, CDCA24Gte, LCA3Gte, DCA24Gte, ISOCHOLabc, PVSATPtu, HCA6Gte, 12DHCHOLabc, 3DHDCAabc, COPROSTabc, TUDCA3Sabc, HDCA24Gte, 3DHCHOLabc, 7DHCHOLabc, HYOCHOLabc, DCA3Gte, 3DHCDCHOLabc, 3HPVSteb, HMR_1897, DSPVSteb, TCDCA3Sabc, 2HATVLACGLUCteb, HCA24Gte, BILDGLCURte, 4HATVACIDteb, 2HATVACIDGLUCteb, 3DHLCAabc, GUDCA3Sabc}
# ACADS is associated with reactions: {r0603, FAOXC183803m, FAOXC2051843m, FAOXC18480m, FAOXC204, ACOAD1fm, FAOXC2251836m, FAOXC16080m, FAOXC1811602m_1, FAOXC16180m, FAOXC140, FAOXC1811601m, FAOXC150m, FAOXC183806m, FAOXC226, r0560, FAOXC2252053m, FAOXC80, FAOXC200180m, FAOXC5C3x, FAOXC204184m, FAOXC161802m, FAOXC160, FAOXC4020m, FAOXC2031836m, FAOXC180, FAOXC18280m, FAOXC182806m, FAOXC1811603m, FAOXC226205m, FAOXC2242046m}
# IVD is associated with reactions: {r0655, ACOAD8m}
# DGKB is associated with reactions: {DAGK_hs}
# ABCC3 is associated with reactions: {GCA3Sabc, UCHOLabc, ICDCHOLabc, LCA3Sabc, TDCA3Sabc, XOL7AH3ATP, LCA24Gte, THCHOLSTOICATP, CA3Sabc, CHOLATEt3, GDCA3Sabc, 7DHCDCHOLabc, HC02194te, TCA3Sabc, XOLDIOLONEATP, CA24Gte, GCDCA3Sabc, ACMPGLUTthc, CDCA24Gte, DCA24Gte, C05463t1, ACMPGLUthc, 3DHCHOLabc, 7DHCHOLabc, ACMPGLUTtep, TCDCA3Sabc, GUDCA3Sabc, THYOCHOLabc, MERACMPtep, HC02195te, XOL7AONEATP, HC02220te, MERACMPthc, CE1273t1, ACMPthc, DCA3Sabc, UDCA3Sabc, HDCA6Gte, SULPACMPtev, ACMPGLUtep, C03990ATP, DHCHOLESTANATEATP, HC02196te, 7KILTCHOLATP, CDCA3Gte, LCA3Gte, ISOCHOLabc, ESTRONEGLCt, r0813, HCA6Gte, 12DHCHOLabc, 3DHDCAabc, COPROSTabc, TUDCA3Sabc, HDCA24Gte, HYOCHOLabc, GCHOLAt3, DCA3Gte, 3DHCDCHOLabc, 3DHLCAabc, HCA24Gte, BILDGLCURte, TCHOLAt3, C04483t1}
# SLCO1B3 is associated with reactions: {DHEASt, TDCA3St, 3DHLCAt, ISOCHOLt, LEUKTRC4t, TCA3St, 3DHCHOLt, 3DHCDCHOLt, TUDCA3St, 7DHCHOLt, GDCA3St, 7DHCDCHOLt, GCA3St, 12DHCHOLt, TCHOLAt, ICDCHOLt, COPROSTt, TCDCA3St, UDCA3St, LCA3St, 3DHDCAt, HC02220t, THYOCHOLt, HYOCHOLt, GCDCA3St, GCHOLAt, UDCHOLt, BILGLCURt, UCHOLt, TRIODTHYt, GUDCA3St, ESTRONESt, C05769te3, DCA3St, CA3St, ESTRADIOLGLCt, C05770te4}
# BLVRA is associated with reactions: {BILIRED2, BILIRED}
# SLC25A10 is associated with reactions: {MALSO4tm, AKGMALtm, r0819, SUCCtm, r0836, FUMSO3tm, r0834, r0822, MALSO3tm, r2420, FUMTSULtm, MALTSULtm, r0835, SUCFUMtm, FUMtm, r0829, MALtm, FUMSO4tm, r0885, r0830, r2419}
# DGKB is associated with reactions: {DAGK_hs}
# SLC25A11 is associated with reactions: {r2520, AKGMALtm}
# SLC13A3 is associated with reactions: {SUCCt4_3, C02712te, CITt4_3, AKGt4_3}
# SLC13A3 is associated with reactions: {AKGt4_3}
# BLVRB is associated with reactions: {BILIRED2, FADRx2, BILIRED}
# PIGB is associated with reactions: {HMR_0765, BMTer_U, H3MTer_U}
# DAO is associated with reactions: {DALAOXx, DORNOp, DARGOp}
# BPNT1 is associated with reactions: {BPNT2, BPNT}
# BTD is associated with reactions: {BTND1, BTND1n, BTNDe, BTNDm}
# AKR1C1 is associated with reactions: {AKR1C1, HMR_2018, HMR_9804, HMR_2016}
# GLRX is associated with reactions: {DASCBR_1}
# AKR1C4 is associated with reactions: {AKR1C42, HMR_9804, HSD3A2r, HMR_1771, r0747, HMR_1743, HMR_2016, AKR1C41, HMR_2018, HSD3A1r, r0750, HMR_1742, HMR_1770}
# SLC5A6 is associated with reactions: {PNTOt5, BTNt3i, BTNt3i_1, PNTOt1, HMR_9608, LIPOti_1, HMR_9609, PNTOt5_1}
# SLC19A3 is associated with reactions: {BTNt4i, THMt3}
# GLRX2 is associated with reactions: {DASCBR_1}
# UPB1 is associated with reactions: {UPPN, BUP2}
# GLRX2 is associated with reactions: {DASCBR_1}
# TM7SF2 is associated with reactions: {HMR_1540, RE3134C, C14STRr, C14STR}
# AKR1D1 is associated with reactions: {AKR1D, AKR1D2, HMR_2014, HMR_1741, HMR_1768, HMR_1769, HMR_1740}
# DDO is associated with reactions: {DASPO1p}
# SLC1A5 is associated with reactions: {ALAASNNaEx, CYSALANaEx, CYSTHRNaEx, ALACYSNaEx, ALASERNaEx, CYSSERNaEx, SERCYSNaEx, ASNALANaEx, GLNALANaEx, ASNGLNNaEx, ALATHRNaEx, THRALANaEx, CYSASNNaEx, THRCYSNaEx, GLNTHRNaEx, SERALANaEx, HDD2CRNte2, ASNTHRNaEx, GLNASNNaEx, SERGLNNaEx, THRSERNaEx, ALAGLNNaEx, ASNSERNaEx, GLNCYSNaEx, SERTHRNaEx, ASNCYSNaEx, THRASNNaEx, SERASNNaEx, CYSGLNNaEx, THRGLNNaEx, GLNSERNaEx}
# NSDHL is associated with reactions: {HMR_1495, C3STDH1, HMR_1551, C3STDH1r, HMR_1546, C3STDH1Pr, C4STMO2r, C4STMO2Pr, HMR_1505}
# HSD17B4 is associated with reactions: {HMR_3076, FAOXC2051843x, FAOXC225C204x, HMR_3072, FAOXC11BRC9BRx, RE3177M, RE1525X, FAOXC183806x, HMR_3064, FAOXC8C6x, RE3082X, PEROXx, RE1526M, RE0512X, FAOXC142C122x, RE3179M, HMR_3096, HMR_3059, HMR_3340, FAOXC2252053x, FAOXC240200x_1, FAOXC160140x, FAOXC22C20x, FAOXC161C141x, HMR_3100, HMR_3328, HSD17B42x_1, FAOXC2452253x, FAOXC2251836x, DEOXFVShc, FAOXC221C201x, RE3156X, FAOXC200180x, HMR_3332, FAOXC121C10x, RE3178M, RE1526X, FAOXC18480x, HSD17B4x, FAOXC15BRC13BRx, FAOXC6C4x, FAOXC81C61x, HMR_3336, FAOXC241C221x, RE0512M, HMR_3344, FAOXC143C123x, FAOXC205C184x, FAOXC8DCC6DCx, FAOXC2452256x, FAOXC123C102x, r0743, RE2991X, FAOXC101C8x, RE1527M, RE3005M, HMR_3348, FAOXC14DCC12DCx, FAOXC241181x, C3STKR2r, FAOXC24C22x, FAOXC164C143x, FAOXC181C161x, FAOXC13BRC11BRx, FAOXC246226x, HMR_3068, FAOXC102C81x, FAOXC226205x, r0744, 3HPVSTETCOAhcx, FAOXC16DCC14DCx, FAOXC120100x, HMR_3352, FAOXC2442246x, r1477, FAOXC163C142x, FAOXC184C163x, PROFVSCOAhc, FAOXC10DCC8DCx, FAOXC184C164x, FOAXC122C101x, FAOXC16080x, FAOXC180x, RE2987X, FAOXC6DCC4DCx, RE1525M, FAOXC61C4x, RE1527X, FAOXC260240x_1, FAOXC12DCC10DCx, HMR_1644, FAOXC141C121x, FAOXC201C181x, FAOXC2242046x, HACD1x, FAOXC140120x, FAOXC10080x, HMR_1706}
# DDO is associated with reactions: {DASPO1p}
# MSMO1 is associated with reactions: {HMR_1490, HMR_1543, HMR_1549, HMR_1494, C4STMO1r, HMR_1493, HMR_1504, HMR_1544, HMR_1502, HMR_1548, HMR_1545, C4STMO2r, HMR_1550, HMR_1503}
# SLC1A4 is associated with reactions: {THRCYSNaEx, SERALANaEx, CYSALANaEx, ALASERNaEx, 4HPROLTASCT1, THRSERNaEx, CYSSERNaEx, ALACYSNaEx, CYSTHRNaEx, SERTHRNaEx, GLUPROASCT1, SERCYSNaEx, ALATHRNaEx, THRALANaEx, ASPPROASCT1}
# ECI1 is associated with reactions: {RE2999M, FAOXC225m, FAOXTC122m, DCIm, FAOXC185m, RE2992M, RE3628M, FAOXC123m, RE3003M, RE1573M, FAOXC163Gm, FAOXC122m, FAOXC184m, HMR_3447, FAOXC61m, FAOXC226m, FAOXC164m, FAOXC102m}
# SLC7A10 is associated with reactions: {CYSGLUexR, SERDGLNexR, ALADGLNexR, THRGLNexR, HMR_9191, ALAGLNexR, SERGLNexR, SERGLYexR, THRGLYexR, SERDGLYexR, ALAGLYexR, CYSGLYex, ALADGLYexR}
# ATP2B3 is associated with reactions: {CAATPS_1}
# ECI2 is associated with reactions: {RE2999M, FAOXC163x, RE3002X, FAOXC102x, DCIm, FAOXC61x, RE2992M, RE3628M, FAOXC184x, FAOXC225x, FAOXC101x, FAOXC123x, FAOXC122x, RE3003M, RE1573M, RE2992X, FAOXC121x, HMR_3447, FAOXC164x, RE1573X}
# ATP2B1 is associated with reactions: {CAATPS_1}
# SLC3A2 is associated with reactions: {PHEyLATthc, CYSGLUexR, GLNyLATthc, HISyLATtc, ALAyLATthc, PTRCARGte, HMR_9191, ALAGLNexR, AMY1e, METyLATthc, ARGN1ASPMDte, CYSGLYex, LEUyLAThtc, SERDGLNexR, LEUt4, METLEUex, HISyLATthc, ALADGLNexR, THRGLNexR, 34DHPHELAT1tc, AMY2e, ARGLYSex, CYSTGLUex, SERGLNexR, SERGLYexR, THRGLYexR, SERDGLYexR, ALAGLYexR, ALADGLYexR}
# DCK is associated with reactions: {DCK2n, DCK1n, ADADir}
# ALAS1 is associated with reactions: {r0517, r0196, ALASm}
# ATP2B4 is associated with reactions: {CAATPS_1}
# DCT is associated with reactions: {DCT}
# SCD is associated with reactions: {HMR_2282, HMR_2284, HMR_2293, DESAT18, DESAT16_2, DESAT18_3, HMR_2287, HMR_2281, DESAT16, DESAT18_5, HMR_2288, r0510, HMR_2295, HMR_2292, HMR_2296, DESAT18_11, HMR_2289, r0511}
# FADS2 is associated with reactions: {DESAT18_12, HMR_2365, DESAT18_9, DESAT18_8, HMR_2359, DESAT24_1, DESAT14_9, HMR_2380, DESAT18_6, HMR_2472, HMR_2368, DESAT18_10, HMR_2484}
# ATP2B2 is associated with reactions: {CAATPS_1}
# GCAT is associated with reactions: {GLYATm, ALASm}
# FADS1 is associated with reactions: {DESAT18_9, HMR_2359, HMR_2380, DESAT20_2, HMR_2472, DESAT20_1, HMR_2368, HMR_2365, HMR_2484}
# ALAS2 is associated with reactions: {r0517, r0196, ALASm}
# DGAT1 is associated with reactions: {DGAT}
# ALAS1 is associated with reactions: {ALASm}
# CAT is associated with reactions: {CATm, CATp, CAT2p}
# DGAT2 is associated with reactions: {DGAT}
# DGUOK is associated with reactions: {DGNSKm}
# SLC8A1 is associated with reactions: {CAt7r}
# SLC8A3 is associated with reactions: {CAt7r}
# DGUOK is associated with reactions: {DGNSKm}
# SLC8A3 is associated with reactions: {CAt7r}
# SLC8A3 is associated with reactions: {CAt7r}
# SLC38A2 is associated with reactions: {GLYt4, PHEt4, ALAt4, SERt4, SELMETHte, GLNt4, HISt4, ASNt4, CYSt4, THRt4, METt4, PROt4}
# DGUOK is associated with reactions: {DGNSKm}
# DGUOK is associated with reactions: {DGNSK, DGNSKm}
# SLC7A1 is associated with reactions: {LYSt5r, PHEt4, ARGt5r, ORNt, ALAt4, LEUt4, HOMt4}
# SLC8A2 is associated with reactions: {CAt7r}
# DGUOK is associated with reactions: {DGNSKm}
# SLC8A3 is associated with reactions: {CAt7r}
# SLC2A3 is associated with reactions: {DHAAt1r, GALt1r, GLCt1, MALTt1r, XYLt, MANt1r}
# SLC8A3 is associated with reactions: {CAt7r}
# SLC8A3 is associated with reactions: {CAt7r}
# MMAA is associated with reactions: {CBL2tm}
# ACE2 is associated with reactions: {RE0937E, GLYt4, PHEt4, SERt4, TYRt4, CYSt4, THRt4, ILEt4, RE2445E, TRPt4, ALAt4, LEUt4, SELMETHte, RE0938E, GLNt4, RE0936E, VALt4, ASNt4, METt4, PROt4}
# SLC7A3 is associated with reactions: {LYSt5r, PHEt4, ARGt5r, ORNt, ALAt4, LEUt4, HOMt4}
# ...
# MTMR7 is associated with reactions: {HMR_6545}
# PLPP7 is associated with reactions: {HMR_6545}
# TNS2 is associated with reactions: {HMR_6545}
# FABP4 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# FABP6 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# DUSP11 is associated with reactions: {HMR_6545}
# FABP7 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# CTDSPL2 is associated with reactions: {HMR_6545}
# PTPRQ is associated with reactions: {HMR_6545}
# FABP2 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# PLPP6 is associated with reactions: {HMR_6545}
# PMPCA is associated with reactions: {HMR_6545}
# FABP5 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# MDP1 is associated with reactions: {HMR_6545}
# FABP9 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# FABP3 is associated with reactions: {HMR_0240, HMR_0322, HMR_0254, HMR_0344, HMR_0270, HMR_0304, HMR_0292, HMR_0191, HMR_0380, HMR_0183, HMR_0300, BUTt, HMR_0326, HMR_0208, HMR_0164, HMR_0203, HMR_0428, HMR_0167, HMR_0384, HMR_0308, HMR_0388, HMR_0232, HMR_0288, HMR_0392, HMR_0170, HMR_0278, HMR_0296, HMR_0176, HMR_0432, HMR_0436, HMR_0244}
# MTMR14 is associated with reactions: {HMR_6545}
# ACSM5 is associated with reactions: {HMR_0168, HMR_0184, HMR_0177, HMR_0156, HMR_0180, HMR_0171, HMR_0165}
# MTMR8 is associated with reactions: {HMR_6545}
# ACSM4 is associated with reactions: {HMR_0168, HMR_0184, HMR_0177, HMR_0156, HMR_0180, HMR_0171, HMR_0165}
# PTPDC1 is associated with reactions: {HMR_6545}
# MINPP1 is associated with reactions: {MITKP}
# ACSM2A is associated with reactions: {HMR_0168, HMR_0184, HMR_0177, HMR_0156, HMR_0180, HMR_0171, HMR_0165}
# ITPK1 is associated with reactions: {ITKPK}
# ACSM3 is associated with reactions: {HMR_0168, HMR_0184, HMR_0177, HMR_0156, HMR_0180, HMR_0171, HMR_0165}
# PIP5KL1 is associated with reactions: {HMR_6580, HMR_6595}
# ACSM2B is associated with reactions: {HMR_0168, HMR_0184, HMR_0177, HMR_0156, HMR_0180, HMR_0171, HMR_0165}
#  is associated with reactions: {ACChex, FACOAE140, HMR_0410, HMR_0434, HMR_0328, HMR_0390, HMR_0438, HMR_0386, HMR_0214, HMR_0366, HMR_0256, HMR_0242, HMR_0406, HMR_0302, HMR_0374, HMR_0276, HMR_0201, FACOAE120, FACOAE161, HMR_0268, FACOAE1836Z9Z12Z, HMR_0394, HMR_0306, HMR_0310, HMR_0422, HMR_0414, HMR_0280, HMR_0358, FACOAE1839Z12Z15Z, HMR_0362, FACOAE1829Z12Z, HMR_0354, HMR_0272, HMR_0234, HMR_0260, HMR_0324, HMR_0298, HMR_0430, HMR_0193, HMR_0382, HMR_0290, HMR_0210, HMR_0418, HMR_0238, HMR_0246, HMR_0346, HMR_0426, HMR_0206, HMR_0378, HMR_0370}
# DHRS9 is associated with reactions: {HMR_6632}
# DHRS3 is associated with reactions: {HMR_6632}
# LRTOMT is associated with reactions: {HMR_6755}
# ABHD5 is associated with reactions: {HMR_0593}
# MBOAT1 is associated with reactions: {HMR_0593}
# DIO1 is associated with reactions: {HMR_6834, HMR_6826, HMR_6854}
# LCLAT1 is associated with reactions: {HMR_0593}
# PLPPR2 is associated with reactions: {HMR_0601, HMR_0767, HMR_0598, HMR_0597}
# LPIN1 is associated with reactions: {SBPP3, HMR_0597, HMR_0598, HMR_0601, HMR_0767}
# DIO3 is associated with reactions: {HMR_6826}
# DIO2 is associated with reactions: {HMR_6834, HMR_6826, HMR_6854}
# SULT1B1 is associated with reactions: {HMR_6838, HMR_6850, HMR_6844}
# SULT1C2 is associated with reactions: {HMR_6838, HMR_6850, HMR_6844}
# PLPP5 is associated with reactions: {HMR_0601, HMR_0767, HMR_0598, HMR_0597}
# PLPPR3 is associated with reactions: {HMR_0601, HMR_0767, HMR_0598, HMR_0597}
# COQ5 is associated with reactions: {HMR_6908}
# PLPPR4 is associated with reactions: {HMR_0601, HMR_0767, HMR_0598, HMR_0597}
# KMT5C is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# EHMT1 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# LPIN3 is associated with reactions: {SBPP3, HMR_0597, HMR_0598, HMR_0601, HMR_0767}
# LPIN2 is associated with reactions: {SBPP3, HMR_0597, HMR_0598, HMR_0601, HMR_0767}
# KMT2B is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# PLPP4 is associated with reactions: {HMR_0601, HMR_0767, HMR_0598, HMR_0597}
# SETDB1 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# EPT1 is associated with reactions: {HMR_0614}
# PLD3 is associated with reactions: {HMR_0642, HMR_0629}
# PLD4 is associated with reactions: {HMR_0642, HMR_0629}
# SETD2 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# PLD6 is associated with reactions: {HMR_0629}
# BCHE is associated with reactions: {HMR_0641}
# SETD7 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# AGK is associated with reactions: {HMR_0678}
# KMT5A is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# DOT1L is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# KMT2A is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# CERS5 is associated with reactions: {HMR_0758, HMR_0750}
# CERS3 is associated with reactions: {HMR_0758, HMR_0750}
# CERS1 is associated with reactions: {HMR_0758, HMR_0750}
# KMT2C is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# CERS6 is associated with reactions: {HMR_0758, HMR_0750}
# ASH1L is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# CERS2 is associated with reactions: {HMR_0758, HMR_0750}
# EHMT2 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# SUV39H1 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# CERS4 is associated with reactions: {HMR_0758, HMR_0750}
# NSD1 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# ASAH2 is associated with reactions: {HMR_0753}
# SETMAR is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# FUT11 is associated with reactions: {HMR_0765}
# SETD1B is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# UGGT1 is associated with reactions: {HMR_0765}
# WHSC1L1 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# FUT4 is associated with reactions: {HMR_0878, HMR_0911, HMR_0765}
# MGAT4D is associated with reactions: {HMR_0765}
# B3GALNT2 is associated with reactions: {HMR_0765}
# ALG1L is associated with reactions: {HMR_0765}
# POMGNT1 is associated with reactions: {HMR_0765}
# SMYD3 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# POGLUT1 is associated with reactions: {HMR_0765}
# SUV39H2 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
#  is associated with reactions: {HMR_0765}
# KMT2E is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# ALG1L2 is associated with reactions: {HMR_0765}
# B4GALT4 is associated with reactions: {HMR_0875, HMR_0890, HMR_0765}
# SETD1A is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# OGT is associated with reactions: {HMR_0765}
# GLT8D1 is associated with reactions: {HMR_0765}
# WHSC1 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# STT3A is associated with reactions: {HMR_0765}
# SETDB2 is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# KMT2D is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# B4GALNT3 is associated with reactions: {HMR_0765}
# KMT5B is associated with reactions: {HMR_6976, HMR_6975, HMR_6977}
# UGGT2 is associated with reactions: {HMR_0765}
# SPCS3 is associated with reactions: {HMR_6978}
# SEC11A is associated with reactions: {HMR_6978}
# MGAT5B is associated with reactions: {HMR_0765}
# SPCS1 is associated with reactions: {HMR_6978}
# FUT7 is associated with reactions: {HMR_0878, HMR_0765}
# GLT6D1 is associated with reactions: {HMR_0765}
# SEC11C is associated with reactions: {HMR_6978}
# SPCS2 is associated with reactions: {HMR_6978}
# DOLPP1 is associated with reactions: {HMR_7256}
# MGAT5 is associated with reactions: {HMR_7328}
# MGAT4C is associated with reactions: {HMR_7329}
# PXDN is associated with reactions: {HMR_7628}
# GCNT7 is associated with reactions: {HMR_0765}
# PXDNL is associated with reactions: {HMR_7628}
# B3GALT1 is associated with reactions: {HMR_0860, HMR_0765}
# PPIP5K1 is associated with reactions: {PMI12346PS}
# PPIP5K2 is associated with reactions: {PMI12346PS}
# STT3B is associated with reactions: {HMR_0765}
# TKFC is associated with reactions: {HMR_7755}
# GLT8D2 is associated with reactions: {HMR_0765}
# FAAH2 is associated with reactions: {HMR_7756}
# B3GNT9 is associated with reactions: {HMR_0765}
# PGM2L1 is associated with reactions: {HMR_8585}
# B3GLCT is associated with reactions: {HMR_0765}
# CES3 is associated with reactions: {HMR_8643}
# B4GALNT2 is associated with reactions: {HMR_0765}
# FUT10 is associated with reactions: {HMR_0765}
# CES5A is associated with reactions: {HMR_8643}
# B4GALNT4 is associated with reactions: {HMR_0765}
# CES1 is associated with reactions: {HMR_8643}
# CLPS is associated with reactions: {HMR_9561}
# SLC47A2 is associated with reactions: {HMR_9619, HMR_9582, HMR_9584}
# GALNTL5 is associated with reactions: {HMR_0765}
# SLC47A1 is associated with reactions: {HMR_9619, HMR_9582, HMR_9584}
# SLC10A6 is associated with reactions: {HMR_9621}
# SLC22A12 is associated with reactions: {HMR_9622}
# B3GALT2 is associated with reactions: {HMR_0860, HMR_0765}
# HYKK is associated with reactions: {HMR_9801}
# GLTP is associated with reactions: {HMR_0770}
# HSD17B14 is associated with reactions: {HMR_9804}
# HEXDC is associated with reactions: {HMR_0808, HMR_0828, HMR_0821, HMR_0836, HMR_0807}
# GLB1L is associated with reactions: {HMR_0819, HMR_0830}
# WWOX is associated with reactions: {HMR_9804}
# ST6GALNAC4 is associated with reactions: {HMR_0823}
# NEU4 is associated with reactions: {HMR_0825, HMR_0847}
# AKR1B15 is associated with reactions: {HMR_9804}
# FUT2 is associated with reactions: {HMR_0864, HMR_0908, HMR_0909}
# DHRS2 is associated with reactions: {HMR_9804}
# FUT5 is associated with reactions: {HMR_0911, HMR_0870, HMR_0873, HMR_8271}
# HTATIP2 is associated with reactions: {HMR_9804}
# SDR9C7 is associated with reactions: {HMR_9804}
# HSD11B1L is associated with reactions: {HMR_9804}
# FUT6 is associated with reactions: {HMR_0911, HMR_0870, HMR_0873, HMR_8271}
# CYP2U1 is associated with reactions: {HMR_2029, HMR_0946, HMR_0942, HMR_2457, HMR_0954, HMR_0950}
# BDH2 is associated with reactions: {HMR_9804}
# GPX8 is associated with reactions: {HMR_0963, HMR_0960}
# CTBP1 is associated with reactions: {HMR_9804}
# DPEP2 is associated with reactions: {HMR_1085}
# SDR42E2 is associated with reactions: {HMR_9804}
# DPEP3 is associated with reactions: {HMR_1085}
# SDR42E1 is associated with reactions: {HMR_9804}
# PTGES3 is associated with reactions: {PGESc}
# CBR4 is associated with reactions: {HMR_9804}
#  is associated with reactions: {HMR_9804}
# SCARF2 is associated with reactions: {HMR_1321}
# ENPP6 is associated with reactions: {HMR_9805}
# RPP14 is associated with reactions: {HMR_1321}
# PHYKPL is associated with reactions: {HMR_9807}
# ALPP is associated with reactions: {HMR_4816}
# AKR1C3 is associated with reactions: {HMR_1325, HMR_2018, HMR_1329, HMR_2016}
# FAXDC2 is associated with reactions: {HMR_1543, HMR_1549, HMR_1494, HMR_1493, HMR_1504, HMR_1544, HMR_1502, HMR_1548, HMR_1545, HMR_1490, HMR_1550, HMR_1503}
# ALPPL2 is associated with reactions: {HMR_4816}
# MAGEA2B is associated with reactions: {HMR_1495}
# SLC51A is associated with reactions: {3DHCHOLt, 3DHLCAt, 3DHDCAt, 12DHCHOLt, THYOCHOLt, HYOCHOLt, 7DHCHOLt, UDCHOLt, 7DHCDCHOLt, 3DHCDCHOLt, UCHOLt, ISOCHOLt, ICDCHOLt, COPROSTt}
# LBR is associated with reactions: {HMR_1540, C14STR}
# SLC51B is associated with reactions: {3DHCHOLt, 3DHLCAt, 3DHDCAt, 12DHCHOLt, THYOCHOLt, HYOCHOLt, 7DHCHOLt, UDCHOLt, 7DHCDCHOLt, 3DHCDCHOLt, UCHOLt, ISOCHOLt, ICDCHOLt, COPROSTt}
# UGT2A1 is associated with reactions: {DCA3GSc, CDCA24GSr, DCA3GSr, LCA24GSc, CDCA24GSc, CA24GSc, HCA24GSr, DCA24GSr, LCA3GSr, CDCA3GSc, HDCA24GSc, CDCA3GSr, LCA24GSr, HCA24GSc, HDCA24GSr, DCA24GSc, CA24GSr, LCA3GSc, HDCA6GSr, HDCA6GSc}
# UGT2A3 is associated with reactions: {CDCA24GSr, HCA24GSc, LCA24GSc, CDCA24GSc, HDCA24GSr, HCA24GSr, LCA3GSr, CDCA3GSc, HDCA24GSc, LCA3GSc, CDCA3GSr, LCA24GSr, HDCA6GSr, HDCA6GSc}
# MYO5B is associated with reactions: {HMR_3345, HMR_3333, HMR_3069, HMR_3097, HMR_3073, HMR_3505, HMR_3341, HMR_3329, HMR_3353, HMR_3349, HMR_3101, HMR_3065, HMR_3337, HMR_1653}
# PON3 is associated with reactions: {PTVSThc, 6MELACAChep, ATVACIDhc, 6HMSMVACIDhep, 3HLVSTAChep, 3HSMVACIDhep, LVSTACIDhep, 6HSMVACIDhep, RSVSPONhc, 4HATVACIDhc, SMVHYDROhep, 6CSMVACIDhep, 2HATVACIDhc, 6HLVSTAChep}
# NPC1 is associated with reactions: {HMR_1916}
# ATP5B is associated with reactions: {ATPS4mi}
# HDLBP is associated with reactions: {HMR_1916}
# ATP5L is associated with reactions: {ATPS4mi}
# ATP5F1 is associated with reactions: {ATPS4mi}
# ATP5H is associated with reactions: {ATPS4mi}
# ATP5D is associated with reactions: {ATPS4mi}
# ATP5J is associated with reactions: {ATPS4mi}
# ATP5O is associated with reactions: {ATPS4mi}
# ATP5J2 is associated with reactions: {ATPS4mi}
# ATP5G1 is associated with reactions: {ATPS4mi}
# ATP5J2 is associated with reactions: {ATPS4mi}
# ATP5C1 is associated with reactions: {ATPS4mi}
# ATP5G3 is associated with reactions: {ATPS4mi}
# ATP5S is associated with reactions: {ATPS4mi}
# ATP5G3 is associated with reactions: {ATPS4mi}
# ATP5E is associated with reactions: {ATPS4mi}
# ATP5D is associated with reactions: {ATPS4mi}
# NSF is associated with reactions: {ATPS4mi}
# ATP5F1 is associated with reactions: {ATPS4mi}
# ATP5G2 is associated with reactions: {ATPS4mi}
# ATP5I is associated with reactions: {ATPS4mi}
# ATP5C1 is associated with reactions: {ATPS4mi}
# ATP5H is associated with reactions: {ATPS4mi}
# ATP5G2 is associated with reactions: {ATPS4mi}
# ATP5F1 is associated with reactions: {ATPS4mi}
# ATP5J is associated with reactions: {ATPS4mi}
# ATP5G1 is associated with reactions: {ATPS4mi}
# ATP5A1 is associated with reactions: {ATPS4mi}
# ATP5L2 is associated with reactions: {ATPS4mi}
# ATP5J is associated with reactions: {ATPS4mi}
# ATP5A1 is associated with reactions: {ATPS4mi}
# ATP5A1 is associated with reactions: {ATPS4mi}
# ATP5G3 is associated with reactions: {ATPS4mi}
# ATP5E is associated with reactions: {ATPS4mi}
# ATP5J is associated with reactions: {ATPS4mi}
# ATP5J2 is associated with reactions: {ATPS4mi}
# ATP5J is associated with reactions: {ATPS4mi}
# UQCRQ is associated with reactions: {CYOOm2i, CYOR_u10mi}
# UQCR11 is associated with reactions: {CYOOm2i, CYOR_u10mi}
# UQCRB is associated with reactions: {CYOOm2i, CYOR_u10mi}
# UQCR10 is associated with reactions: {CYOOm2i, CYOR_u10mi}
# CYTB is associated with reactions: {CYOOm2i, CYOR_u10mi}
