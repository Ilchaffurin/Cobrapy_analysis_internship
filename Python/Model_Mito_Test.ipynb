# %%
import cobra
from cobra.core import Metabolite, Reaction, Model
from d3flux import flux_map
import cobra.test

# %%
 iAS253=cobra.io.read_sbml_model("Models/12918_2011_715èMOESM4_ESM.xml")
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# Adding exchange reaction EX_C00000_b with default bounds for boundary metabolite: C00000_b.
# Adding exchange reaction EX_C00001_b with default bounds for boundary metabolite: C00001_b.
# Adding exchange reaction EX_C00002_b with default bounds for boundary metabolite: C00002_b.
# Adding exchange reaction EX_C00003_b with default bounds for boundary metabolite: C00003_b.
# Adding exchange reaction EX_C00007_b with default bounds for boundary metabolite: C00007_b.
# Adding exchange reaction EX_C00008_b with default bounds for boundary metabolite: C00008_b.
# Adding exchange reaction EX_C00009_b with default bounds for boundary metabolite: C00009_b.
# Adding exchange reaction EX_C00010_b with default bounds for boundary metabolite: C00010_b.
# ...

# %%
print(iAS253.summary())
# Out:
# Objective
# ...
# 1.0 BioMass5 = 139.4264015672118
#
# Uptake
# ------
# Metabolite    Reaction      Flux  C-Number C-Flux
#   C00007_b EX_C00007_b      19.8         0  0.00%
#   C00047_b EX_C00047_b    0.0298         0  0.00%
#   C00049_b EX_C00049_b    0.1524         0  0.00%
#   C00062_b EX_C00062_b    0.0068         0  0.00%
#   C00065_b EX_C00065_b 7.334E-05         0  0.00%
#   C00080_b EX_C00080_b     1.687         0  0.00%
#   C00148_b EX_C00148_b    0.0044         0  0.00%
#   C00183_b EX_C00183_b    0.0106         0  0.00%
#   C00186_b EX_C00186_b     0.575         0  0.00%
#   C00249_b EX_C00249_b    0.4118         0  0.00%
#   C00267_b EX_C00267_b       0.9         0  0.00%
#   C00288_b EX_C00288_b    0.0039         0  0.00%
#   C00407_b EX_C00407_b    0.0039         0  0.00%
#   C01089_b EX_C01089_b       0.7         0  0.00%
#
# Secretion
# ---------
# Metabolite    Reaction       Flux  C-Number C-Flux
#   C00000_b EX_C00000_b     -139.4         0  0.00%
# ...

# %%
for g in iAS253.metabolites:
    print(g)
# Out:
# C00000Cyto
# C00001Cyto
# C00002Cyto
# C00003Cyto
# C00004Cyto
# C00007Cyto
# C00008Cyto
# C00009Cyto
# C00010Cyto
# C00011Cyto
# C00013Cyto
# C00015Cyto
# C00016Cyto
# C00020Cyto
# C00022Cyto
# C00025Cyto
# C00026Cyto
# C00035Cyto
# C00036Cyto
# C00037Cyto
# C00042Cyto
# C00047Cyto
# C00049Cyto
# C00051Cyto
# C00059Cyto
# C00062Cyto
# C00064Cyto
# C00068Cyto
# C00073Cyto
# C00074Cyto
# C00077Cyto
# C00078Cyto
# C00079Cyto
# C00080Cyto
# C00082Cyto
# C00084Cyto
# C00086Cyto
# C00093Cyto
# C00094Cyto
# C00097Cyto
# C00111Cyto
# C00112Cyto
# C00116Cyto
# C00118Cyto
# C00122Cyto
# C00123Cyto
# C00131Cyto
# C00135Cyto
# C00148Cyto
# C00149Cyto
# C00152Cyto
# C00154Cyto
# C00157Cyto
# C00158Cyto
# C00163Cyto
# C00164Cyto
# C00183Cyto
# C00186Cyto
# C00197Cyto
# C00206Cyto
# C00236Cyto
# C00246Cyto
# C00249Cyto
# C00267Cyto
# C00286Cyto
# C00311Cyto
# C00318Cyto
# C00320Cyto
# C00322Cyto
# C00327Cyto
# C00350Cyto
# C00361Cyto
# C00363Cyto
# C00407Cyto
# C00430Cyto
# C00458Cyto
# ...
